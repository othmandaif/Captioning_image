# %% [markdown]
# ## download data

# %%
# create a data directory
# !mkdir data_dir
 
# download images and annotations to the data directory
# !wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip -P ./data_dir/
# !wget http://images.cocodataset.org/zips/train2014.zip -P ./data_dir/
# !wget http://images.cocodataset.org/zips/val2014.zip -P ./data_dir/
    
# extract zipped images and annotations and remove the zip files
# !unzip ./data_dir/annotations_trainval2014.zip -d ./data_dir/
# !rm ./data_dir/annotations_trainval2014.zip
# !unzip ./data_dir/train2014.zip -d ./data_dir/
# !rm ./data_dir/train2014.zip 
# !unzip ./data_dir/val2014.zip -d ./data_dir/ 
# !rm ./data_dir/val2014.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  extracting: ./data_dir/val2014/COCO_val2014_000000535608.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000279145.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000243495.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000225791.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000428067.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000059383.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000558498.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000376123.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000191304.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000171062.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000014549.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000121152.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000276596.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000029431.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000036349.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000502055.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000438848.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000364973.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000564166.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000323327.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000338581.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000039656.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000071667.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000376046.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000066394.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000277584.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000383518.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000262466.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000153055.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000155312.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000010440.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000541108.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000202503.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000161308.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000153013.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000089924.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000289842.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000191226.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000157465.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000218224.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000030548.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000347422.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000451501.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000374401.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000274599.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000285235.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000298691.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000319726.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000137822.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000566697.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000280017.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000240436.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000368459.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000107831.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000051976.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000476349.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000252829.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000197716.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000222458.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000277738.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000213649.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000406050.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000301735.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000467752.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000126229.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000397404.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000402405.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000350721.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000187271.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000011699.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000335644.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000262189.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000109313.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000348905.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000269964.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000242679.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000579893.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000198163.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000154230.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000222696.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000261097.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000368242.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000310711.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000282942.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000199203.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000459598.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000083331.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000442019.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000571038.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000019624.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000367582.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000308785.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000248019.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000064121.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000172924.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000236784.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000253940.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000368684.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000429530.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000390689.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000075884.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000243104.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000464006.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000155051.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000075857.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000464317.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000071284.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000228197.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000451463.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000394050.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000249129.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000102741.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000231806.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000052340.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000108541.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000317147.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000300784.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000105480.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000225184.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000348162.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000416787.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000167017.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000157019.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000027756.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000561088.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000209898.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000131453.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000417846.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000215244.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000328397.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000324500.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000116208.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000507893.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000157944.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000398507.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000515540.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000211119.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000233023.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000091402.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000239627.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000235564.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000205300.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000139512.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000459502.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000117719.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000229000.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000170000.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000005860.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000494427.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000030423.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000467951.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000204830.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000432239.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000402992.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000472416.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000414852.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000047367.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000352549.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000552075.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000170232.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000363654.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000047435.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000283717.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000504810.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000517249.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000532580.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000571857.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000257470.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000386553.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000542939.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000252342.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000027433.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000337969.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000168974.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000417193.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000096539.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000442979.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000411674.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000121783.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000156858.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000265208.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000100087.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000528575.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000077396.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000206770.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000549171.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000290078.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000227884.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000024285.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000526394.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000235747.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000022215.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000252911.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000002684.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000075611.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000106193.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000193194.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000184446.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000021903.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000045388.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000063855.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000215062.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000189378.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000237844.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000161569.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000563311.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000154431.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000276146.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000578545.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000161605.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000078426.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000488563.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000375015.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000551669.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000152111.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000242246.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000283005.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000450055.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000081004.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000353180.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000471991.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000007072.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000117201.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000177383.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000369309.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000157046.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000561054.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000175933.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000186977.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000297578.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000316423.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000576015.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000262654.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000022371.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000023272.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000434192.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000046872.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000428375.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000333887.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000365386.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000043613.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000033979.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000451102.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000498392.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000093333.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000566975.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000104327.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000115584.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000531349.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000396692.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000075591.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000236837.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000190291.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000449856.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000173217.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000095707.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000192620.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000328091.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000398377.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000549674.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000053677.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000256903.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000248953.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000269254.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000321008.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000536183.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000007506.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000439710.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000089432.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000063240.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000472795.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000030668.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000315162.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000553780.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000444207.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000358055.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000504125.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000541197.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000320150.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000000761.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000561062.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000581183.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000010684.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000251404.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000107840.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000037470.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000373170.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000465272.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000275219.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000457559.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000111004.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000332845.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000573258.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000555119.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000154711.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000233223.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000184994.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000056129.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000102654.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000255470.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000506471.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000483643.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000013721.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000309678.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000173772.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000070657.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000313398.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000148508.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000281725.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000514376.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000153103.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000197870.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000560566.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000575916.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000040729.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000223857.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000528311.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000459662.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000136285.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000277521.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000451095.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000292905.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000448259.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000550084.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000328372.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000433554.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000144896.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000095078.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000271681.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000148730.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000041899.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000216861.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000137211.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000250311.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000093611.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000408535.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000240751.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000297323.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000537513.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000459428.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000279013.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000394840.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000454326.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000434494.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000087493.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000581332.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000133210.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000430473.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000504635.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000357176.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000464296.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000224862.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000538513.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000409867.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000172649.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000099736.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000204360.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000520478.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000565389.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000058111.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000238258.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000318730.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000209904.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000247438.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000214664.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000561514.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000457249.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000213593.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000409125.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000026670.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000542451.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000052966.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000191738.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000309510.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000531875.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000010217.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000050125.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000568290.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000488374.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000413839.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000287828.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000022158.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000516020.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000377406.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000245793.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000453438.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000450719.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000581253.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000241668.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000485368.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000426309.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000450129.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000454102.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000011742.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000113756.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000274063.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000067959.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000077282.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000143215.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000508822.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000321742.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000346687.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000078093.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000139099.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000342929.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000111117.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000522791.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000363039.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000523780.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000249936.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000404897.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000553869.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000570094.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000121188.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000165919.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000576827.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000045648.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000167356.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000203024.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000057323.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000432293.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000363344.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000052527.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000475678.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000495980.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000187876.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000481159.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000097964.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000208050.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000230150.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000059207.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000389129.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000462324.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000071239.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000148282.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000580418.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000204887.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000292347.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000522175.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000209747.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000500473.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000311883.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000573891.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000281625.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000265596.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000031093.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000482574.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000044723.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000045966.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000012860.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000006688.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000552979.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000078537.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000533408.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000482367.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000275695.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000442993.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000192787.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000299838.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000579240.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000529698.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000164759.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000476175.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000548879.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000094865.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000354121.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000483358.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000353982.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000428336.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000278843.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000419378.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000439007.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000262003.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000196919.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000342933.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000513417.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000428140.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000154701.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000510734.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000005600.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000208740.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000212346.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000063661.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000270593.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000482160.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000565954.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000455483.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000484531.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000166563.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000541132.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000445972.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000116951.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000288076.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000365752.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000063521.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000560361.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000293057.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000460347.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000255950.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000238866.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000376236.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000512657.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000487482.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000052413.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000155478.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000470070.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000065270.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000505663.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000021394.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000060049.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000449432.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000552942.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000208406.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000070332.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000143927.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000527374.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000338941.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000191613.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000434142.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000572347.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000109827.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000355450.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000050054.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000317565.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000476415.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000083059.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000155571.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000128516.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000467696.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000001668.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000128978.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000181888.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000069906.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000275058.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000056400.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000531178.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000211141.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000115006.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000225130.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000126974.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000223426.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000356302.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000177535.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000064842.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000036124.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000207670.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000516372.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000355819.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000141524.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000327917.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000567205.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000413538.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000050926.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000124232.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000209788.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000124210.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000530052.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000208107.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000398554.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000018193.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000318671.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000555050.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000408501.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000521419.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000234660.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000492758.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000330790.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000515577.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000388409.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000377231.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000292931.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000577976.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000442480.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000320026.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000460944.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000455343.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000209147.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000066231.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000405547.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000379441.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000519853.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000130651.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000301282.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000511050.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000075001.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000416818.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000572802.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000558114.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000249884.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000294209.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000388398.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000485580.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000402858.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000204749.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000111259.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000136173.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000462289.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000294134.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000522727.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000141172.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000335833.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000573391.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000410496.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000277971.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000228604.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000109819.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000214274.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000313888.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000247918.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000030407.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000458781.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000372246.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000554273.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000135797.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000443537.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000245320.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000274800.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000346259.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000104906.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000107375.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000053229.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000579337.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000032193.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000357824.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000541123.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000578467.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000149890.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000241677.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000247259.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000068352.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000560011.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000009420.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000295768.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000450404.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000189740.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000278601.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000289899.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000475413.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000503311.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000527447.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000216894.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000509514.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000360064.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000432276.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000311531.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000340503.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000053958.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000084312.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000367689.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000008493.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000005673.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000079657.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000440358.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000359838.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000384651.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000129548.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000213156.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000145009.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000040011.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000128939.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000330091.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000290179.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000501080.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000217228.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000292033.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000334466.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000201163.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000415672.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000329568.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000291412.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000403584.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000352027.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000520933.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000140542.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000281429.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000299448.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000323751.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000192403.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000042215.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000093735.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000327983.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000573179.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000546463.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000077178.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000381551.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000120584.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000035760.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000505492.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000432120.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000426275.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000461655.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000362712.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000374858.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000204232.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000041773.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000229207.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000255665.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000569862.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000483656.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000044524.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000019559.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000550471.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000210228.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000130401.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000237324.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000229599.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000419223.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000146315.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000473728.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000463599.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000105751.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000485148.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000270244.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000246308.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000297425.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000344439.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000022874.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000214703.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000352206.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000490643.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000447328.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000327315.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000014038.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000126340.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000295138.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000433676.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000246064.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000147132.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000118124.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000515214.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000360762.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000376393.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000061805.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000066064.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000244019.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000268215.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000365626.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000390184.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000502136.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000386035.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000230795.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000244455.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000434129.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000248767.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000161227.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000559707.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000441686.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000032724.jpg
# ...
#  extracting: ./data_dir/val2014/COCO_val2014_000000027585.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000047651.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000109291.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000434657.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000467107.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000055077.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000529626.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000065306.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000279265.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000173471.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000298493.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000401991.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000236432.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000100245.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000456833.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000208516.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000375980.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000236338.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000385115.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000069138.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000362483.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000110630.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000206757.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000468953.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000479613.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000270609.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000044877.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000279305.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000229553.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000170393.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000083065.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000229358.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000046269.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000394892.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000448861.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000187329.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000429386.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000527363.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000400596.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000224974.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000341128.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000134034.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000263612.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000476282.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000542211.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000383322.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000165202.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000563175.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000050756.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000115379.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000141517.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000404618.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000218026.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000253988.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000265151.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000269419.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000503490.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000567013.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000072000.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000546934.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000364299.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000170191.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000469242.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000138556.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000295006.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000502275.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000103163.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000573066.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000323442.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000305195.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000018575.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000249825.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000209431.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000076334.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000129855.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000251094.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000030595.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000539423.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000266727.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000469877.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000156246.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000222866.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000366295.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000030353.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000078465.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000099182.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000423396.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000211618.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000150301.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000537692.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000078488.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000257053.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000489799.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000235857.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000497351.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000133515.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000314426.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000283131.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000322511.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000479078.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000238598.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000046405.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000198724.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000279838.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000507739.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000064859.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000393423.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000405205.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000442040.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000221272.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000565273.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000158849.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000448205.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000243344.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000393267.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000401018.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000137619.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000367804.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000206260.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000446850.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000300989.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000449180.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000201727.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000182469.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000243852.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000409030.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000294776.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000136941.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000204098.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000182050.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000215596.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000228214.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000406071.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000397459.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000203509.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000293300.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000142934.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000523297.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000485290.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000484425.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000120535.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000180584.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000313228.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000486580.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000563762.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000099481.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000213599.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000062060.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000283028.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000366711.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000308388.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000364133.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000544237.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000199989.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000290282.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000542042.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000274014.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000318022.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000207437.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000461885.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000562708.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000272015.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000541744.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000183786.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000577853.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000181488.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000330079.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000107963.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000327433.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000485343.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000435444.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000324584.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000536235.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000226848.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000270316.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000165831.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000240301.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000144003.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000308167.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000269918.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000400915.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000270677.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000506803.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000094174.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000005443.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000157084.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000437895.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000078499.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000219269.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000117028.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000073470.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000316499.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000351554.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000164779.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000154139.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000258911.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000041373.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000466005.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000066523.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000332877.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000514294.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000070945.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000199927.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000206751.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000036077.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000201045.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000079490.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000079566.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000086988.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000560266.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000254834.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000190783.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000524575.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000433156.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000532620.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000533171.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000074462.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000386584.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000575625.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000000599.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000316123.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000442206.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000411665.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000112698.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000395462.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000368663.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000399049.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000479939.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000132860.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000281315.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000014526.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000154892.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000535313.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000008483.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000259087.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000030667.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000132288.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000155617.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000049682.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000382438.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000488693.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000324492.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000543836.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000551804.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000045516.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000347233.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000154202.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000038210.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000113113.jpg
#  extracting: ./data_dir/val2014/COCO_val2014_000000441814.jpg

# %% [markdown]
# ## import dependencies

# %%
import os
import nltk
import pickle
import numpy as np
from PIL import Image
from collections import Counter
from pycocotools.coco import COCO
import matplotlib.pyplot as plt
 
import torch
import torch.nn as nn
import torch.utils.data as data
from torchvision import transforms
import torchvision.models as models
import torchvision.transforms as transforms
from torch.nn.utils.rnn import pack_padded_sequence

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## build vocab

# %%
class Vocab(object):
    """Simple vocabulary wrapper."""
    def __init__(self):
        self.w2i = {}
        self.i2w = {}
        self.index = 0
 
    def __call__(self, token):
        if not token in self.w2i:
            return self.w2i['<unk>']
        return self.w2i[token]
 
    def __len__(self):
        return len(self.w2i)
    def add_token(self, token):
        if not token in self.w2i:
            self.w2i[token] = self.index
            self.i2w[self.index] = token
            self.index += 1

def build_vocabulary(json, threshold):
    """Build a simple vocabulary wrapper."""
    coco = COCO(json)
    counter = Counter()
    ids = coco.anns.keys()
    for i, id in enumerate(ids):
        caption = str(coco.anns[id]['caption'])
        tokens = nltk.tokenize.word_tokenize(caption.lower())
        counter.update(tokens)
 
        if (i+1) % 1000 == 0:
            print("[{}/{}] Tokenized the captions.".format(i+1, len(ids)))
 
    # If the word frequency is less than 'threshold', then the word is discarded.
    tokens = [token for token, cnt in counter.items() if cnt >= threshold]
 
    # Create a vocab wrapper and add some special tokens.
    vocab = Vocab()
    vocab.add_token('<pad>')
    vocab.add_token('<start>')
    vocab.add_token('<end>')
    vocab.add_token('<unk>')
 
    # Add the words to the vocabulary.
    for i, token in enumerate(tokens):
        vocab.add_token(token)
    return vocab
 
vocab = build_vocabulary(json='data_dir/annotations/captions_train2014.json', threshold=4)
vocab_path = './data_dir/vocabulary.pkl'
with open(vocab_path, 'wb') as f:
    pickle.dump(vocab, f)
print("Total vocabulary size: {}".format(len(vocab)))
print("Saved the vocabulary wrapper to '{}'".format(vocab_path))
# Out:
# loading annotations into memory...
# Done (t=1.30s)
# creating index...
# index created!
# [1000/414113] Tokenized the captions.
# [2000/414113] Tokenized the captions.
# [3000/414113] Tokenized the captions.
# [4000/414113] Tokenized the captions.
# [5000/414113] Tokenized the captions.
# [6000/414113] Tokenized the captions.
# [7000/414113] Tokenized the captions.
# [8000/414113] Tokenized the captions.
# [9000/414113] Tokenized the captions.
# [10000/414113] Tokenized the captions.
# [11000/414113] Tokenized the captions.
# [12000/414113] Tokenized the captions.
# [13000/414113] Tokenized the captions.
# [14000/414113] Tokenized the captions.
# [15000/414113] Tokenized the captions.
# [16000/414113] Tokenized the captions.
# [17000/414113] Tokenized the captions.
# [18000/414113] Tokenized the captions.
# [19000/414113] Tokenized the captions.
# [20000/414113] Tokenized the captions.
# [21000/414113] Tokenized the captions.
# [22000/414113] Tokenized the captions.
# [23000/414113] Tokenized the captions.
# [24000/414113] Tokenized the captions.
# [25000/414113] Tokenized the captions.
# [26000/414113] Tokenized the captions.
# [27000/414113] Tokenized the captions.
# [28000/414113] Tokenized the captions.
# [29000/414113] Tokenized the captions.
# [30000/414113] Tokenized the captions.
# [31000/414113] Tokenized the captions.
# [32000/414113] Tokenized the captions.
# [33000/414113] Tokenized the captions.
# [34000/414113] Tokenized the captions.
# [35000/414113] Tokenized the captions.
# [36000/414113] Tokenized the captions.
# [37000/414113] Tokenized the captions.
# [38000/414113] Tokenized the captions.
# [39000/414113] Tokenized the captions.
# [40000/414113] Tokenized the captions.
# [41000/414113] Tokenized the captions.
# [42000/414113] Tokenized the captions.
# [43000/414113] Tokenized the captions.
# [44000/414113] Tokenized the captions.
# [45000/414113] Tokenized the captions.
# [46000/414113] Tokenized the captions.
# [47000/414113] Tokenized the captions.
# [48000/414113] Tokenized the captions.
# [49000/414113] Tokenized the captions.
# [50000/414113] Tokenized the captions.
# [51000/414113] Tokenized the captions.
# [52000/414113] Tokenized the captions.
# [53000/414113] Tokenized the captions.
# [54000/414113] Tokenized the captions.
# [55000/414113] Tokenized the captions.
# [56000/414113] Tokenized the captions.
# [57000/414113] Tokenized the captions.
# [58000/414113] Tokenized the captions.
# [59000/414113] Tokenized the captions.
# [60000/414113] Tokenized the captions.
# [61000/414113] Tokenized the captions.
# [62000/414113] Tokenized the captions.
# [63000/414113] Tokenized the captions.
# [64000/414113] Tokenized the captions.
# [65000/414113] Tokenized the captions.
# [66000/414113] Tokenized the captions.
# [67000/414113] Tokenized the captions.
# [68000/414113] Tokenized the captions.
# [69000/414113] Tokenized the captions.
# [70000/414113] Tokenized the captions.
# [71000/414113] Tokenized the captions.
# [72000/414113] Tokenized the captions.
# [73000/414113] Tokenized the captions.
# [74000/414113] Tokenized the captions.
# [75000/414113] Tokenized the captions.
# [76000/414113] Tokenized the captions.
# [77000/414113] Tokenized the captions.
# [78000/414113] Tokenized the captions.
# [79000/414113] Tokenized the captions.
# [80000/414113] Tokenized the captions.
# [81000/414113] Tokenized the captions.
# [82000/414113] Tokenized the captions.
# [83000/414113] Tokenized the captions.
# [84000/414113] Tokenized the captions.
# [85000/414113] Tokenized the captions.
# [86000/414113] Tokenized the captions.
# [87000/414113] Tokenized the captions.
# [88000/414113] Tokenized the captions.
# [89000/414113] Tokenized the captions.
# [90000/414113] Tokenized the captions.
# [91000/414113] Tokenized the captions.
# [92000/414113] Tokenized the captions.
# [93000/414113] Tokenized the captions.
# [94000/414113] Tokenized the captions.
# [95000/414113] Tokenized the captions.
# [96000/414113] Tokenized the captions.
# [97000/414113] Tokenized the captions.
# [98000/414113] Tokenized the captions.
# [99000/414113] Tokenized the captions.
# [100000/414113] Tokenized the captions.
# [101000/414113] Tokenized the captions.
# [102000/414113] Tokenized the captions.
# [103000/414113] Tokenized the captions.
# [104000/414113] Tokenized the captions.
# [105000/414113] Tokenized the captions.
# [106000/414113] Tokenized the captions.
# [107000/414113] Tokenized the captions.
# [108000/414113] Tokenized the captions.
# [109000/414113] Tokenized the captions.
# [110000/414113] Tokenized the captions.
# [111000/414113] Tokenized the captions.
# [112000/414113] Tokenized the captions.
# [113000/414113] Tokenized the captions.
# [114000/414113] Tokenized the captions.
# [115000/414113] Tokenized the captions.
# [116000/414113] Tokenized the captions.
# [117000/414113] Tokenized the captions.
# [118000/414113] Tokenized the captions.
# [119000/414113] Tokenized the captions.
# [120000/414113] Tokenized the captions.
# [121000/414113] Tokenized the captions.
# [122000/414113] Tokenized the captions.
# [123000/414113] Tokenized the captions.
# [124000/414113] Tokenized the captions.
# [125000/414113] Tokenized the captions.
# [126000/414113] Tokenized the captions.
# [127000/414113] Tokenized the captions.
# [128000/414113] Tokenized the captions.
# [129000/414113] Tokenized the captions.
# [130000/414113] Tokenized the captions.
# [131000/414113] Tokenized the captions.
# [132000/414113] Tokenized the captions.
# [133000/414113] Tokenized the captions.
# [134000/414113] Tokenized the captions.
# [135000/414113] Tokenized the captions.
# [136000/414113] Tokenized the captions.
# [137000/414113] Tokenized the captions.
# [138000/414113] Tokenized the captions.
# [139000/414113] Tokenized the captions.
# [140000/414113] Tokenized the captions.
# [141000/414113] Tokenized the captions.
# [142000/414113] Tokenized the captions.
# [143000/414113] Tokenized the captions.
# [144000/414113] Tokenized the captions.
# [145000/414113] Tokenized the captions.
# [146000/414113] Tokenized the captions.
# [147000/414113] Tokenized the captions.
# [148000/414113] Tokenized the captions.
# [149000/414113] Tokenized the captions.
# [150000/414113] Tokenized the captions.
# [151000/414113] Tokenized the captions.
# [152000/414113] Tokenized the captions.
# [153000/414113] Tokenized the captions.
# [154000/414113] Tokenized the captions.
# [155000/414113] Tokenized the captions.
# [156000/414113] Tokenized the captions.
# [157000/414113] Tokenized the captions.
# [158000/414113] Tokenized the captions.
# [159000/414113] Tokenized the captions.
# [160000/414113] Tokenized the captions.
# [161000/414113] Tokenized the captions.
# [162000/414113] Tokenized the captions.
# [163000/414113] Tokenized the captions.
# [164000/414113] Tokenized the captions.
# [165000/414113] Tokenized the captions.
# [166000/414113] Tokenized the captions.
# [167000/414113] Tokenized the captions.
# [168000/414113] Tokenized the captions.
# [169000/414113] Tokenized the captions.
# [170000/414113] Tokenized the captions.
# [171000/414113] Tokenized the captions.
# [172000/414113] Tokenized the captions.
# [173000/414113] Tokenized the captions.
# [174000/414113] Tokenized the captions.
# [175000/414113] Tokenized the captions.
# [176000/414113] Tokenized the captions.
# [177000/414113] Tokenized the captions.
# [178000/414113] Tokenized the captions.
# [179000/414113] Tokenized the captions.
# [180000/414113] Tokenized the captions.
# [181000/414113] Tokenized the captions.
# [182000/414113] Tokenized the captions.
# [183000/414113] Tokenized the captions.
# [184000/414113] Tokenized the captions.
# [185000/414113] Tokenized the captions.
# [186000/414113] Tokenized the captions.
# [187000/414113] Tokenized the captions.
# [188000/414113] Tokenized the captions.
# [189000/414113] Tokenized the captions.
# [190000/414113] Tokenized the captions.
# [191000/414113] Tokenized the captions.
# [192000/414113] Tokenized the captions.
# [193000/414113] Tokenized the captions.
# [194000/414113] Tokenized the captions.
# [195000/414113] Tokenized the captions.
# [196000/414113] Tokenized the captions.
# [197000/414113] Tokenized the captions.
# [198000/414113] Tokenized the captions.
# [199000/414113] Tokenized the captions.
# [200000/414113] Tokenized the captions.
# [201000/414113] Tokenized the captions.
# [202000/414113] Tokenized the captions.
# [203000/414113] Tokenized the captions.
# [204000/414113] Tokenized the captions.
# [205000/414113] Tokenized the captions.
# [206000/414113] Tokenized the captions.
# [207000/414113] Tokenized the captions.
# [208000/414113] Tokenized the captions.
# [209000/414113] Tokenized the captions.
# [210000/414113] Tokenized the captions.
# [211000/414113] Tokenized the captions.
# [212000/414113] Tokenized the captions.
# [213000/414113] Tokenized the captions.
# [214000/414113] Tokenized the captions.
# [215000/414113] Tokenized the captions.
# [216000/414113] Tokenized the captions.
# [217000/414113] Tokenized the captions.
# [218000/414113] Tokenized the captions.
# [219000/414113] Tokenized the captions.
# [220000/414113] Tokenized the captions.
# [221000/414113] Tokenized the captions.
# [222000/414113] Tokenized the captions.
# [223000/414113] Tokenized the captions.
# [224000/414113] Tokenized the captions.
# [225000/414113] Tokenized the captions.
# [226000/414113] Tokenized the captions.
# [227000/414113] Tokenized the captions.
# [228000/414113] Tokenized the captions.
# [229000/414113] Tokenized the captions.
# [230000/414113] Tokenized the captions.
# [231000/414113] Tokenized the captions.
# [232000/414113] Tokenized the captions.
# [233000/414113] Tokenized the captions.
# [234000/414113] Tokenized the captions.
# [235000/414113] Tokenized the captions.
# [236000/414113] Tokenized the captions.
# [237000/414113] Tokenized the captions.
# [238000/414113] Tokenized the captions.
# [239000/414113] Tokenized the captions.
# [240000/414113] Tokenized the captions.
# [241000/414113] Tokenized the captions.
# [242000/414113] Tokenized the captions.
# [243000/414113] Tokenized the captions.
# [244000/414113] Tokenized the captions.
# [245000/414113] Tokenized the captions.
# [246000/414113] Tokenized the captions.
# [247000/414113] Tokenized the captions.
# [248000/414113] Tokenized the captions.
# [249000/414113] Tokenized the captions.
# [250000/414113] Tokenized the captions.
# [251000/414113] Tokenized the captions.
# [252000/414113] Tokenized the captions.
# [253000/414113] Tokenized the captions.
# [254000/414113] Tokenized the captions.
# [255000/414113] Tokenized the captions.
# [256000/414113] Tokenized the captions.
# [257000/414113] Tokenized the captions.
# [258000/414113] Tokenized the captions.
# [259000/414113] Tokenized the captions.
# [260000/414113] Tokenized the captions.
# [261000/414113] Tokenized the captions.
# [262000/414113] Tokenized the captions.
# [263000/414113] Tokenized the captions.
# [264000/414113] Tokenized the captions.
# [265000/414113] Tokenized the captions.
# [266000/414113] Tokenized the captions.
# [267000/414113] Tokenized the captions.
# [268000/414113] Tokenized the captions.
# [269000/414113] Tokenized the captions.
# [270000/414113] Tokenized the captions.
# [271000/414113] Tokenized the captions.
# [272000/414113] Tokenized the captions.
# [273000/414113] Tokenized the captions.
# [274000/414113] Tokenized the captions.
# [275000/414113] Tokenized the captions.
# [276000/414113] Tokenized the captions.
# [277000/414113] Tokenized the captions.
# [278000/414113] Tokenized the captions.
# [279000/414113] Tokenized the captions.
# [280000/414113] Tokenized the captions.
# [281000/414113] Tokenized the captions.
# [282000/414113] Tokenized the captions.
# [283000/414113] Tokenized the captions.
# [284000/414113] Tokenized the captions.
# [285000/414113] Tokenized the captions.
# [286000/414113] Tokenized the captions.
# [287000/414113] Tokenized the captions.
# [288000/414113] Tokenized the captions.
# [289000/414113] Tokenized the captions.
# [290000/414113] Tokenized the captions.
# [291000/414113] Tokenized the captions.
# [292000/414113] Tokenized the captions.
# [293000/414113] Tokenized the captions.
# [294000/414113] Tokenized the captions.
# [295000/414113] Tokenized the captions.
# [296000/414113] Tokenized the captions.
# [297000/414113] Tokenized the captions.
# [298000/414113] Tokenized the captions.
# [299000/414113] Tokenized the captions.
# [300000/414113] Tokenized the captions.
# [301000/414113] Tokenized the captions.
# [302000/414113] Tokenized the captions.
# [303000/414113] Tokenized the captions.
# [304000/414113] Tokenized the captions.
# [305000/414113] Tokenized the captions.
# [306000/414113] Tokenized the captions.
# [307000/414113] Tokenized the captions.
# [308000/414113] Tokenized the captions.
# [309000/414113] Tokenized the captions.
# [310000/414113] Tokenized the captions.
# [311000/414113] Tokenized the captions.
# [312000/414113] Tokenized the captions.
# [313000/414113] Tokenized the captions.
# [314000/414113] Tokenized the captions.
# [315000/414113] Tokenized the captions.
# [316000/414113] Tokenized the captions.
# [317000/414113] Tokenized the captions.
# [318000/414113] Tokenized the captions.
# [319000/414113] Tokenized the captions.
# [320000/414113] Tokenized the captions.
# [321000/414113] Tokenized the captions.
# [322000/414113] Tokenized the captions.
# [323000/414113] Tokenized the captions.
# [324000/414113] Tokenized the captions.
# [325000/414113] Tokenized the captions.
# [326000/414113] Tokenized the captions.
# [327000/414113] Tokenized the captions.
# [328000/414113] Tokenized the captions.
# [329000/414113] Tokenized the captions.
# [330000/414113] Tokenized the captions.
# [331000/414113] Tokenized the captions.
# [332000/414113] Tokenized the captions.
# [333000/414113] Tokenized the captions.
# [334000/414113] Tokenized the captions.
# [335000/414113] Tokenized the captions.
# [336000/414113] Tokenized the captions.
# [337000/414113] Tokenized the captions.
# [338000/414113] Tokenized the captions.
# [339000/414113] Tokenized the captions.
# [340000/414113] Tokenized the captions.
# [341000/414113] Tokenized the captions.
# [342000/414113] Tokenized the captions.
# [343000/414113] Tokenized the captions.
# [344000/414113] Tokenized the captions.
# [345000/414113] Tokenized the captions.
# [346000/414113] Tokenized the captions.
# [347000/414113] Tokenized the captions.
# [348000/414113] Tokenized the captions.
# [349000/414113] Tokenized the captions.
# [350000/414113] Tokenized the captions.
# [351000/414113] Tokenized the captions.
# [352000/414113] Tokenized the captions.
# [353000/414113] Tokenized the captions.
# [354000/414113] Tokenized the captions.
# [355000/414113] Tokenized the captions.
# [356000/414113] Tokenized the captions.
# [357000/414113] Tokenized the captions.
# [358000/414113] Tokenized the captions.
# [359000/414113] Tokenized the captions.
# [360000/414113] Tokenized the captions.
# [361000/414113] Tokenized the captions.
# [362000/414113] Tokenized the captions.
# [363000/414113] Tokenized the captions.
# [364000/414113] Tokenized the captions.
# [365000/414113] Tokenized the captions.
# [366000/414113] Tokenized the captions.
# [367000/414113] Tokenized the captions.
# [368000/414113] Tokenized the captions.
# [369000/414113] Tokenized the captions.
# [370000/414113] Tokenized the captions.
# [371000/414113] Tokenized the captions.
# [372000/414113] Tokenized the captions.
# [373000/414113] Tokenized the captions.
# [374000/414113] Tokenized the captions.
# [375000/414113] Tokenized the captions.
# [376000/414113] Tokenized the captions.
# [377000/414113] Tokenized the captions.
# [378000/414113] Tokenized the captions.
# [379000/414113] Tokenized the captions.
# [380000/414113] Tokenized the captions.
# [381000/414113] Tokenized the captions.
# [382000/414113] Tokenized the captions.
# [383000/414113] Tokenized the captions.
# [384000/414113] Tokenized the captions.
# [385000/414113] Tokenized the captions.
# [386000/414113] Tokenized the captions.
# [387000/414113] Tokenized the captions.
# [388000/414113] Tokenized the captions.
# [389000/414113] Tokenized the captions.
# [390000/414113] Tokenized the captions.
# [391000/414113] Tokenized the captions.
# [392000/414113] Tokenized the captions.
# [393000/414113] Tokenized the captions.
# [394000/414113] Tokenized the captions.
# [395000/414113] Tokenized the captions.
# [396000/414113] Tokenized the captions.
# [397000/414113] Tokenized the captions.
# [398000/414113] Tokenized the captions.
# [399000/414113] Tokenized the captions.
# [400000/414113] Tokenized the captions.
# [401000/414113] Tokenized the captions.
# [402000/414113] Tokenized the captions.
# [403000/414113] Tokenized the captions.
# [404000/414113] Tokenized the captions.
# [405000/414113] Tokenized the captions.
# [406000/414113] Tokenized the captions.
# [407000/414113] Tokenized the captions.
# [408000/414113] Tokenized the captions.
# [409000/414113] Tokenized the captions.
# [410000/414113] Tokenized the captions.
# [411000/414113] Tokenized the captions.
# [412000/414113] Tokenized the captions.
# [413000/414113] Tokenized the captions.
# [414000/414113] Tokenized the captions.
# Total vocabulary size: 9948
# Saved the vocabulary wrapper to './data_dir/vocabulary.pkl'

# %% [markdown]
# ## resize images

# %%
def reshape_image(image, shape):
    """Resize an image to the given shape."""
    return image.resize(shape, Image.ANTIALIAS)
 
def reshape_images(image_path, output_path, shape):
    """Reshape the images in 'image_path' and save into 'output_path'."""
    if not os.path.exists(output_path):
        os.makedirs(output_path)
 
    images = os.listdir(image_path)
    num_im = len(images)
    for i, im in enumerate(images):
        with open(os.path.join(image_path, im), 'r+b') as f:
            with Image.open(f) as image:
                image = reshape_image(image, shape)
                image.save(os.path.join(output_path, im), image.format)
        if (i+1) % 100 == 0:
            print ("[{}/{}] Resized the images and saved into '{}'."
                   .format(i+1, num_im, output_path))

image_path = './data_dir/train2014/'
output_path = './data_dir/resized_images/'
image_shape = [256, 256]
reshape_images(image_path, output_path, image_shape)
# Out:
# [100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [1900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [2900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [3900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [4900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [5900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [6900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [7900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [8900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [9900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [10900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [11900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [12900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [13900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [14900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [15900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [16900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [17900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [18900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [19900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [20900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [21900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [22900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [23900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [24900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [25900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [26900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [27900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [28900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [29900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [30900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [31900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [32900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [33900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [34900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [35900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [36900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [37900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [38900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [39900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [40900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [41900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [42900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [43900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [44900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [45900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [46900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [47900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [48900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [49900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [50900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [51900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [52900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [53900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [54900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [55900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [56900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [57900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [58900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [59900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [60900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [61000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [61100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [61200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [61300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [61400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [61500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [61600/82783] Resized the images and saved into './data_dir/resized_images/'.
# ...
# [62300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [62400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [62500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [62600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [62700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [62800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [62900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [63900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [64900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [65900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [66900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [67900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [68900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [69900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [70900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [71900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [72900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [73900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [74900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [75900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [76900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [77900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [78900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [79900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [80900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81700/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81800/82783] Resized the images and saved into './data_dir/resized_images/'.
# [81900/82783] Resized the images and saved into './data_dir/resized_images/'.
# [82000/82783] Resized the images and saved into './data_dir/resized_images/'.
# [82100/82783] Resized the images and saved into './data_dir/resized_images/'.
# [82200/82783] Resized the images and saved into './data_dir/resized_images/'.
# [82300/82783] Resized the images and saved into './data_dir/resized_images/'.
# [82400/82783] Resized the images and saved into './data_dir/resized_images/'.
# [82500/82783] Resized the images and saved into './data_dir/resized_images/'.
# [82600/82783] Resized the images and saved into './data_dir/resized_images/'.
# [82700/82783] Resized the images and saved into './data_dir/resized_images/'.

# %% [markdown]
# ## instantiate data loader

# %%
class CustomCocoDataset(data.Dataset):
    """COCO Custom Dataset compatible with torch.utils.data.DataLoader."""
    def __init__(self, data_path, coco_json_path, vocabulary, transform=None):
        """Set the path for images, captions and vocabulary wrapper.
        
        Args:
            root: image directory.
            json: coco annotation file path.
            vocab: vocabulary wrapper.
            transform: image transformer.
        """
        self.root = data_path
        self.coco_data = COCO(coco_json_path)
        self.indices = list(self.coco_data.anns.keys())
        self.vocabulary = vocabulary
        self.transform = transform
 
    def __getitem__(self, idx):
        """Returns one data pair (image and caption)."""
        coco_data = self.coco_data
        vocabulary = self.vocabulary
        annotation_id = self.indices[idx]
        caption = coco_data.anns[annotation_id]['caption']
        image_id = coco_data.anns[annotation_id]['image_id']
        image_path = coco_data.loadImgs(image_id)[0]['file_name']
 
        image = Image.open(os.path.join(self.root, image_path)).convert('RGB')
        if self.transform is not None:
            image = self.transform(image)
 
        # Convert caption (string) to word ids.
        word_tokens = nltk.tokenize.word_tokenize(str(caption).lower())
        caption = []
        caption.append(vocabulary('<start>'))
        caption.extend([vocabulary(token) for token in word_tokens])
        caption.append(vocabulary('<end>'))
        ground_truth = torch.Tensor(caption)
        return image, ground_truth
 
    def __len__(self):
        return len(self.indices)
 
 
def collate_function(data_batch):
    """Creates mini-batch tensors from the list of tuples (image, caption).
    
    We should build custom collate_fn rather than using default collate_fn, 
    because merging caption (including padding) is not supported in default.
    Args:
        data: list of tuple (image, caption). 
            - image: torch tensor of shape (3, 256, 256).
            - caption: torch tensor of shape (?); variable length.
    Returns:
        images: torch tensor of shape (batch_size, 3, 256, 256).
        targets: torch tensor of shape (batch_size, padded_length).
        lengths: list; valid length for each padded caption.
    """
    # Sort a data list by caption length (descending order).
    data_batch.sort(key=lambda d: len(d[1]), reverse=True)
    imgs, caps = zip(*data_batch)
 
    # Merge images (from list of 3D tensors to 4D tensor).
    # Originally, imgs is a list of <batch_size> number of RGB images with dimensions (3, 256, 256)
    # This line of code turns it into a single tensor of dimensions (<batch_size>, 3, 256, 256)
    imgs = torch.stack(imgs, 0)
 
    # Merge captions (from list of 1D tensors to 2D tensor), similar to merging of images donw above.
    cap_lens = [len(cap) for cap in caps]
    tgts = torch.zeros(len(caps), max(cap_lens)).long()
    for i, cap in enumerate(caps):
        end = cap_lens[i]
        tgts[i, :end] = cap[:end]        
    return imgs, tgts, cap_lens
 
def get_loader(data_path, coco_json_path, vocabulary, transform, batch_size, shuffle, num_workers):
    """Returns torch.utils.data.DataLoader for custom coco dataset."""
    # COCO caption dataset
    coco_dataser = CustomCocoDataset(data_path=data_path,
                       coco_json_path=coco_json_path,
                       vocabulary=vocabulary,
                       transform=transform)
    
    # Data loader for COCO dataset
    # This will return (images, captions, lengths) for each iteration.
    # images: a tensor of shape (batch_size, 3, 224, 224).
    # captions: a tensor of shape (batch_size, padded_length).
    # lengths: a list indicating valid length for each caption. length is (batch_size).
    custom_data_loader = torch.utils.data.DataLoader(dataset=coco_dataser, 
                                              batch_size=batch_size,
                                              shuffle=shuffle,
                                              num_workers=num_workers,
                                              collate_fn=collate_function)
    return custom_data_loader

# %% [markdown]
# ## model definition

# %%
class CNNModel(nn.Module):
    def __init__(self, embedding_size):
        """Load the pretrained ResNet-152 and replace top fc layer."""
        super(CNNModel, self).__init__()
        resnet = models.resnet152(pretrained=True)
        module_list = list(resnet.children())[:-1]      # delete the last fc layer.
        self.resnet_module = nn.Sequential(*module_list)
        self.linear_layer = nn.Linear(resnet.fc.in_features, embedding_size)
        self.batch_norm = nn.BatchNorm1d(embedding_size, momentum=0.01)
        
    def forward(self, input_images):
        """Extract feature vectors from input images."""
        with torch.no_grad():
            resnet_features = self.resnet_module(input_images)
        resnet_features = resnet_features.reshape(resnet_features.size(0), -1)
        final_features = self.batch_norm(self.linear_layer(resnet_features))
        return final_features
 
 
class LSTMModel(nn.Module):
    def __init__(self, embedding_size, hidden_layer_size, vocabulary_size, num_layers, max_seq_len=20):
        """Set the hyper-parameters and build the layers."""
        super(LSTMModel, self).__init__()
        self.embedding_layer = nn.Embedding(vocabulary_size, embedding_size)
        self.lstm_layer = nn.LSTM(embedding_size, hidden_layer_size, num_layers, batch_first=True)
        self.linear_layer = nn.Linear(hidden_layer_size, vocabulary_size)
        self.max_seq_len = max_seq_len
        
    def forward(self, input_features, capts, lens):
        """Decode image feature vectors and generates captions."""
        embeddings = self.embedding_layer(caps)
        embeddings = torch.cat((input_features.unsqueeze(1), embeddings), 1)
        lstm_input = pack_padded_sequence(embeddings, lens, batch_first=True) 
        hidden_variables, _ = self.lstm_layer(lstm_input)
        model_outputs = self.linear_layer(hidden_variables[0])
        return model_outputs
    
    def sample(self, input_features, lstm_states=None):
        """Generate captions for given image features using greedy search."""
        sampled_indices = []
        lstm_inputs = input_features.unsqueeze(1)
        for i in range(self.max_seq_len):
            hidden_variables, lstm_states = self.lstm_layer(lstm_inputs, lstm_states)          # hiddens: (batch_size, 1, hidden_size)
            model_outputs = self.linear_layer(hidden_variables.squeeze(1))            # outputs:  (batch_size, vocab_size)
            _, predicted_outputs = model_outputs.max(1)                        # predicted: (batch_size)
            sampled_indices.append(predicted_outputs)
            lstm_inputs = self.embedding_layer(predicted_outputs)                       # inputs: (batch_size, embed_size)
            lstm_inputs = lstm_inputs.unsqueeze(1)                         # inputs: (batch_size, 1, embed_size)
        sampled_indices = torch.stack(sampled_indices, 1)                # sampled_ids: (batch_size, max_seq_length)
        return sampled_indices

# %% [markdown]
# ## training loop

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# Create model directory
if not os.path.exists('models_dir/'):
    os.makedirs('models_dir/')

    
# Image preprocessing, normalization for the pretrained resnet
transform = transforms.Compose([ 
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip(), 
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), 
                         (0.229, 0.224, 0.225))])


# Load vocabulary wrapper
with open('data_dir/vocabulary.pkl', 'rb') as f:
    vocabulary = pickle.load(f)

    
# Build data loader
custom_data_loader = get_loader('data_dir/resized_images', 'data_dir/annotations/captions_train2014.json', vocabulary, 
                         transform, 128,
                         shuffle=True, num_workers=2) 


# Build the models
encoder_model = CNNModel(256).to(device)
decoder_model = LSTMModel(256, 512, len(vocabulary), 1).to(device)
 
    
# Loss and optimizer
loss_criterion = nn.CrossEntropyLoss()
parameters = list(decoder_model.parameters()) + list(encoder_model.linear_layer.parameters()) + list(encoder_model.batch_norm.parameters())
optimizer = torch.optim.Adam(parameters, lr=0.001)


# Train the models
total_num_steps = len(custom_data_loader)
for epoch in range(5):
    for i, (imgs, caps, lens) in enumerate(custom_data_loader):
 
        # Set mini-batch dataset
        imgs = imgs.to(device)
        caps = caps.to(device)
        tgts = pack_padded_sequence(caps, lens, batch_first=True)[0]
 
        # Forward, backward and optimize
        feats = encoder_model(imgs)
        outputs = decoder_model(feats, caps, lens)
        loss = loss_criterion(outputs, tgts)
        decoder_model.zero_grad()
        encoder_model.zero_grad()
        loss.backward()
        optimizer.step()
 
        # Print log info
        if i % 10 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Perplexity: {:5.4f}'
                  .format(epoch, 5, i, total_num_steps, loss.item(), np.exp(loss.item()))) 
 
        # Save the model checkpoints
        if (i+1) % 1000 == 0:
            torch.save(decoder_model.state_dict(), os.path.join(
                'models_dir/', 'decoder-{}-{}.ckpt'.format(epoch+1, i+1)))
            torch.save(encoder_model.state_dict(), os.path.join(
                'models_dir/', 'encoder-{}-{}.ckpt'.format(epoch+1, i+1)))
# Out:
# loading annotations into memory...
# Done (t=0.90s)
# creating index...
# index created!
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]
# Epoch [0/5], Step [0/3236], Loss: 9.2114, Perplexity: 10010.8218
# Epoch [0/5], Step [10/3236], Loss: 5.8685, Perplexity: 353.7117
# Epoch [0/5], Step [20/3236], Loss: 5.1858, Perplexity: 178.7249
# Epoch [0/5], Step [30/3236], Loss: 4.7841, Perplexity: 119.5921
# Epoch [0/5], Step [40/3236], Loss: 4.7207, Perplexity: 112.2519
# Epoch [0/5], Step [50/3236], Loss: 4.3733, Perplexity: 79.3023
# Epoch [0/5], Step [60/3236], Loss: 4.3942, Perplexity: 80.9818
# Epoch [0/5], Step [70/3236], Loss: 3.9490, Perplexity: 51.8850
# Epoch [0/5], Step [80/3236], Loss: 4.0563, Perplexity: 57.7623
# Epoch [0/5], Step [90/3236], Loss: 3.8624, Perplexity: 47.5792
# Epoch [0/5], Step [100/3236], Loss: 3.9071, Perplexity: 49.7523
# Epoch [0/5], Step [110/3236], Loss: 3.8390, Perplexity: 46.4774
# Epoch [0/5], Step [120/3236], Loss: 3.7895, Perplexity: 44.2335
# Epoch [0/5], Step [130/3236], Loss: 3.6995, Perplexity: 40.4254
# Epoch [0/5], Step [140/3236], Loss: 3.7305, Perplexity: 41.6986
# Epoch [0/5], Step [150/3236], Loss: 3.7306, Perplexity: 41.7052
# Epoch [0/5], Step [160/3236], Loss: 3.5296, Perplexity: 34.1119
# Epoch [0/5], Step [170/3236], Loss: 3.5494, Perplexity: 34.7917
# Epoch [0/5], Step [180/3236], Loss: 3.3519, Perplexity: 28.5577
# Epoch [0/5], Step [190/3236], Loss: 3.5031, Perplexity: 33.2183
# Epoch [0/5], Step [200/3236], Loss: 3.4652, Perplexity: 31.9838
# Epoch [0/5], Step [210/3236], Loss: 3.3373, Perplexity: 28.1442
# Epoch [0/5], Step [220/3236], Loss: 3.1464, Perplexity: 23.2530
# Epoch [0/5], Step [230/3236], Loss: 3.2460, Perplexity: 25.6871
# Epoch [0/5], Step [240/3236], Loss: 3.3850, Perplexity: 29.5172
# Epoch [0/5], Step [250/3236], Loss: 3.2739, Perplexity: 26.4152
# Epoch [0/5], Step [260/3236], Loss: 3.2426, Perplexity: 25.6007
# Epoch [0/5], Step [270/3236], Loss: 3.2506, Perplexity: 25.8062
# Epoch [0/5], Step [280/3236], Loss: 3.1954, Perplexity: 24.4204
# Epoch [0/5], Step [290/3236], Loss: 3.0523, Perplexity: 21.1637
# Epoch [0/5], Step [300/3236], Loss: 3.3471, Perplexity: 28.4207
# Epoch [0/5], Step [310/3236], Loss: 2.9606, Perplexity: 19.3098
# Epoch [0/5], Step [320/3236], Loss: 3.0064, Perplexity: 20.2140
# Epoch [0/5], Step [330/3236], Loss: 3.1305, Perplexity: 22.8856
# Epoch [0/5], Step [340/3236], Loss: 3.2558, Perplexity: 25.9409
# Epoch [0/5], Step [350/3236], Loss: 3.1380, Perplexity: 23.0579
# Epoch [0/5], Step [360/3236], Loss: 3.0949, Perplexity: 22.0850
# Epoch [0/5], Step [370/3236], Loss: 3.1472, Perplexity: 23.2706
# Epoch [0/5], Step [380/3236], Loss: 2.9906, Perplexity: 19.8972
# Epoch [0/5], Step [390/3236], Loss: 3.0962, Perplexity: 22.1143
# Epoch [0/5], Step [400/3236], Loss: 3.2268, Perplexity: 25.1992
# Epoch [0/5], Step [410/3236], Loss: 3.0358, Perplexity: 20.8186
# Epoch [0/5], Step [420/3236], Loss: 2.9293, Perplexity: 18.7136
# Epoch [0/5], Step [430/3236], Loss: 2.9775, Perplexity: 19.6393
# Epoch [0/5], Step [440/3236], Loss: 2.7937, Perplexity: 16.3419
# Epoch [0/5], Step [450/3236], Loss: 2.8351, Perplexity: 17.0328
# Epoch [0/5], Step [460/3236], Loss: 2.9310, Perplexity: 18.7472
# Epoch [0/5], Step [470/3236], Loss: 2.9921, Perplexity: 19.9267
# Epoch [0/5], Step [480/3236], Loss: 2.9596, Perplexity: 19.2911
# Epoch [0/5], Step [490/3236], Loss: 2.7730, Perplexity: 16.0072
# Epoch [0/5], Step [500/3236], Loss: 2.7845, Perplexity: 16.1922
# Epoch [0/5], Step [510/3236], Loss: 2.8131, Perplexity: 16.6609
# Epoch [0/5], Step [520/3236], Loss: 2.8212, Perplexity: 16.7977
# Epoch [0/5], Step [530/3236], Loss: 2.7272, Perplexity: 15.2894
# Epoch [0/5], Step [540/3236], Loss: 2.7864, Perplexity: 16.2229
# Epoch [0/5], Step [550/3236], Loss: 2.9307, Perplexity: 18.7411
# Epoch [0/5], Step [560/3236], Loss: 2.8942, Perplexity: 18.0699
# Epoch [0/5], Step [570/3236], Loss: 2.9076, Perplexity: 18.3133
# Epoch [0/5], Step [580/3236], Loss: 2.8272, Perplexity: 16.8976
# Epoch [0/5], Step [590/3236], Loss: 2.7220, Perplexity: 15.2100
# Epoch [0/5], Step [600/3236], Loss: 2.8858, Perplexity: 17.9182
# Epoch [0/5], Step [610/3236], Loss: 2.6583, Perplexity: 14.2726
# Epoch [0/5], Step [620/3236], Loss: 2.8959, Perplexity: 18.1002
# Epoch [0/5], Step [630/3236], Loss: 2.8225, Perplexity: 16.8197
# Epoch [0/5], Step [640/3236], Loss: 2.7870, Perplexity: 16.2316
# Epoch [0/5], Step [650/3236], Loss: 2.8991, Perplexity: 18.1580
# Epoch [0/5], Step [660/3236], Loss: 2.7497, Perplexity: 15.6386
# Epoch [0/5], Step [670/3236], Loss: 2.7659, Perplexity: 15.8935
# Epoch [0/5], Step [680/3236], Loss: 2.7994, Perplexity: 16.4347
# Epoch [0/5], Step [690/3236], Loss: 2.8177, Perplexity: 16.7382
# Epoch [0/5], Step [700/3236], Loss: 2.7206, Perplexity: 15.1890
# Epoch [0/5], Step [710/3236], Loss: 2.7878, Perplexity: 16.2448
# Epoch [0/5], Step [720/3236], Loss: 2.6278, Perplexity: 13.8429
# Epoch [0/5], Step [730/3236], Loss: 2.7838, Perplexity: 16.1804
# Epoch [0/5], Step [740/3236], Loss: 2.6616, Perplexity: 14.3194
# Epoch [0/5], Step [750/3236], Loss: 2.6271, Perplexity: 13.8342
# Epoch [0/5], Step [760/3236], Loss: 2.6914, Perplexity: 14.7528
# Epoch [0/5], Step [770/3236], Loss: 2.6989, Perplexity: 14.8634
# Epoch [0/5], Step [780/3236], Loss: 2.6418, Perplexity: 14.0385
# Epoch [0/5], Step [790/3236], Loss: 2.6334, Perplexity: 13.9210
# Epoch [0/5], Step [800/3236], Loss: 2.7500, Perplexity: 15.6431
# Epoch [0/5], Step [810/3236], Loss: 2.6126, Perplexity: 13.6340
# Epoch [0/5], Step [820/3236], Loss: 2.5571, Perplexity: 12.8987
# Epoch [0/5], Step [830/3236], Loss: 2.5738, Perplexity: 13.1156
# Epoch [0/5], Step [840/3236], Loss: 2.5663, Perplexity: 13.0178
# Epoch [0/5], Step [850/3236], Loss: 2.7722, Perplexity: 15.9943
# Epoch [0/5], Step [860/3236], Loss: 2.5180, Perplexity: 12.4034
# Epoch [0/5], Step [870/3236], Loss: 2.5839, Perplexity: 13.2489
# Epoch [0/5], Step [880/3236], Loss: 2.4944, Perplexity: 12.1144
# Epoch [0/5], Step [890/3236], Loss: 2.5999, Perplexity: 13.4618
# Epoch [0/5], Step [900/3236], Loss: 2.6301, Perplexity: 13.8758
# Epoch [0/5], Step [910/3236], Loss: 2.5723, Perplexity: 13.0964
# Epoch [0/5], Step [920/3236], Loss: 2.6026, Perplexity: 13.4984
# Epoch [0/5], Step [930/3236], Loss: 2.5843, Perplexity: 13.2537
# Epoch [0/5], Step [940/3236], Loss: 2.6356, Perplexity: 13.9515
# Epoch [0/5], Step [950/3236], Loss: 2.6343, Perplexity: 13.9331
# Epoch [0/5], Step [960/3236], Loss: 2.6178, Perplexity: 13.7057
# Epoch [0/5], Step [970/3236], Loss: 2.7287, Perplexity: 15.3126
# Epoch [0/5], Step [980/3236], Loss: 2.6565, Perplexity: 14.2458
# Epoch [0/5], Step [990/3236], Loss: 2.6003, Perplexity: 13.4672
# Epoch [0/5], Step [1000/3236], Loss: 2.6801, Perplexity: 14.5861
# Epoch [0/5], Step [1010/3236], Loss: 2.6509, Perplexity: 14.1669
# Epoch [0/5], Step [1020/3236], Loss: 2.4345, Perplexity: 11.4100
# Epoch [0/5], Step [1030/3236], Loss: 2.5002, Perplexity: 12.1851
# Epoch [0/5], Step [1040/3236], Loss: 2.7330, Perplexity: 15.3785
# Epoch [0/5], Step [1050/3236], Loss: 2.3936, Perplexity: 10.9533
# Epoch [0/5], Step [1060/3236], Loss: 2.4936, Perplexity: 12.1047
# Epoch [0/5], Step [1070/3236], Loss: 2.5639, Perplexity: 12.9864
# Epoch [0/5], Step [1080/3236], Loss: 2.4971, Perplexity: 12.1475
# Epoch [0/5], Step [1090/3236], Loss: 2.5406, Perplexity: 12.6879
# Epoch [0/5], Step [1100/3236], Loss: 2.4504, Perplexity: 11.5924
# Epoch [0/5], Step [1110/3236], Loss: 2.5302, Perplexity: 12.5560
# Epoch [0/5], Step [1120/3236], Loss: 2.5212, Perplexity: 12.4432
# Epoch [0/5], Step [1130/3236], Loss: 2.5089, Perplexity: 12.2912
# Epoch [0/5], Step [1140/3236], Loss: 2.4279, Perplexity: 11.3355
# Epoch [0/5], Step [1150/3236], Loss: 2.3735, Perplexity: 10.7346
# Epoch [0/5], Step [1160/3236], Loss: 2.6492, Perplexity: 14.1428
# Epoch [0/5], Step [1170/3236], Loss: 2.4469, Perplexity: 11.5527
# Epoch [0/5], Step [1180/3236], Loss: 2.6243, Perplexity: 13.7953
# Epoch [0/5], Step [1190/3236], Loss: 2.4395, Perplexity: 11.4672
# Epoch [0/5], Step [1200/3236], Loss: 2.5644, Perplexity: 12.9928
# Epoch [0/5], Step [1210/3236], Loss: 2.4641, Perplexity: 11.7532
# Epoch [0/5], Step [1220/3236], Loss: 2.5429, Perplexity: 12.7170
# Epoch [0/5], Step [1230/3236], Loss: 2.4636, Perplexity: 11.7468
# Epoch [0/5], Step [1240/3236], Loss: 2.6396, Perplexity: 14.0076
# Epoch [0/5], Step [1250/3236], Loss: 2.6022, Perplexity: 13.4929
# Epoch [0/5], Step [1260/3236], Loss: 2.5711, Perplexity: 13.0798
# Epoch [0/5], Step [1270/3236], Loss: 2.5890, Perplexity: 13.3161
# Epoch [0/5], Step [1280/3236], Loss: 2.5069, Perplexity: 12.2665
# Epoch [0/5], Step [1290/3236], Loss: 2.3883, Perplexity: 10.8946
# Epoch [0/5], Step [1300/3236], Loss: 2.4726, Perplexity: 11.8532
# Epoch [0/5], Step [1310/3236], Loss: 2.4783, Perplexity: 11.9210
# Epoch [0/5], Step [1320/3236], Loss: 2.6241, Perplexity: 13.7917
# Epoch [0/5], Step [1330/3236], Loss: 2.4265, Perplexity: 11.3189
# Epoch [0/5], Step [1340/3236], Loss: 2.3358, Perplexity: 10.3378
# Epoch [0/5], Step [1350/3236], Loss: 2.5716, Perplexity: 13.0864
# Epoch [0/5], Step [1360/3236], Loss: 2.4695, Perplexity: 11.8160
# Epoch [0/5], Step [1370/3236], Loss: 2.5283, Perplexity: 12.5321
# Epoch [0/5], Step [1380/3236], Loss: 2.4801, Perplexity: 11.9424
# Epoch [0/5], Step [1390/3236], Loss: 2.3124, Perplexity: 10.0981
# Epoch [0/5], Step [1400/3236], Loss: 2.4367, Perplexity: 11.4351
# Epoch [0/5], Step [1410/3236], Loss: 2.5019, Perplexity: 12.2060
# Epoch [0/5], Step [1420/3236], Loss: 2.4124, Perplexity: 11.1603
# Epoch [0/5], Step [1430/3236], Loss: 2.5366, Perplexity: 12.6372
# Epoch [0/5], Step [1440/3236], Loss: 2.3497, Perplexity: 10.4821
# Epoch [0/5], Step [1450/3236], Loss: 2.4198, Perplexity: 11.2433
# Epoch [0/5], Step [1460/3236], Loss: 2.5396, Perplexity: 12.6744
# Epoch [0/5], Step [1470/3236], Loss: 2.5248, Perplexity: 12.4889
# Epoch [0/5], Step [1480/3236], Loss: 2.4840, Perplexity: 11.9886
# Epoch [0/5], Step [1490/3236], Loss: 2.5604, Perplexity: 12.9406
# Epoch [0/5], Step [1500/3236], Loss: 2.4237, Perplexity: 11.2873
# Epoch [0/5], Step [1510/3236], Loss: 2.5517, Perplexity: 12.8289
# Epoch [0/5], Step [1520/3236], Loss: 2.4712, Perplexity: 11.8368
# Epoch [0/5], Step [1530/3236], Loss: 2.5011, Perplexity: 12.1964
# Epoch [0/5], Step [1540/3236], Loss: 2.4901, Perplexity: 12.0625
# Epoch [0/5], Step [1550/3236], Loss: 2.5079, Perplexity: 12.2794
# Epoch [0/5], Step [1560/3236], Loss: 2.2581, Perplexity: 9.5647
# Epoch [0/5], Step [1570/3236], Loss: 2.4659, Perplexity: 11.7738
# Epoch [0/5], Step [1580/3236], Loss: 2.3281, Perplexity: 10.2588
# Epoch [0/5], Step [1590/3236], Loss: 2.4995, Perplexity: 12.1768
# Epoch [0/5], Step [1600/3236], Loss: 2.4689, Perplexity: 11.8095
# Epoch [0/5], Step [1610/3236], Loss: 2.4326, Perplexity: 11.3882
# Epoch [0/5], Step [1620/3236], Loss: 2.3274, Perplexity: 10.2511
# Epoch [0/5], Step [1630/3236], Loss: 2.4038, Perplexity: 11.0656
# Epoch [0/5], Step [1640/3236], Loss: 2.5937, Perplexity: 13.3791
# Epoch [0/5], Step [1650/3236], Loss: 2.4478, Perplexity: 11.5629
# Epoch [0/5], Step [1660/3236], Loss: 2.4457, Perplexity: 11.5389
# Epoch [0/5], Step [1670/3236], Loss: 2.3413, Perplexity: 10.3950
# Epoch [0/5], Step [1680/3236], Loss: 2.4699, Perplexity: 11.8209
# Epoch [0/5], Step [1690/3236], Loss: 2.4952, Perplexity: 12.1244
# Epoch [0/5], Step [1700/3236], Loss: 2.2890, Perplexity: 9.8652
# Epoch [0/5], Step [1710/3236], Loss: 2.3820, Perplexity: 10.8268
# Epoch [0/5], Step [1720/3236], Loss: 2.4870, Perplexity: 12.0251
# Epoch [0/5], Step [1730/3236], Loss: 2.4046, Perplexity: 11.0743
# Epoch [0/5], Step [1740/3236], Loss: 2.5733, Perplexity: 13.1085
# Epoch [0/5], Step [1750/3236], Loss: 2.3799, Perplexity: 10.8039
# Epoch [0/5], Step [1760/3236], Loss: 2.4531, Perplexity: 11.6241
# Epoch [0/5], Step [1770/3236], Loss: 2.1756, Perplexity: 8.8074
# Epoch [0/5], Step [1780/3236], Loss: 2.4809, Perplexity: 11.9524
# Epoch [0/5], Step [1790/3236], Loss: 2.4089, Perplexity: 11.1222
# Epoch [0/5], Step [1800/3236], Loss: 2.4714, Perplexity: 11.8386
# Epoch [0/5], Step [1810/3236], Loss: 2.1492, Perplexity: 8.5783
# Epoch [0/5], Step [1820/3236], Loss: 2.4195, Perplexity: 11.2403
# Epoch [0/5], Step [1830/3236], Loss: 2.4088, Perplexity: 11.1208
# Epoch [0/5], Step [1840/3236], Loss: 2.3363, Perplexity: 10.3433
# Epoch [0/5], Step [1850/3236], Loss: 2.1777, Perplexity: 8.8263
# Epoch [0/5], Step [1860/3236], Loss: 2.4113, Perplexity: 11.1486
# Epoch [0/5], Step [1870/3236], Loss: 2.5425, Perplexity: 12.7112
# Epoch [0/5], Step [1880/3236], Loss: 2.2033, Perplexity: 9.0547
# Epoch [0/5], Step [1890/3236], Loss: 2.3519, Perplexity: 10.5058
# Epoch [0/5], Step [1900/3236], Loss: 2.4249, Perplexity: 11.3010
# Epoch [0/5], Step [1910/3236], Loss: 2.3463, Perplexity: 10.4472
# Epoch [0/5], Step [1920/3236], Loss: 2.4315, Perplexity: 11.3764
# Epoch [0/5], Step [1930/3236], Loss: 2.4041, Perplexity: 11.0685
# Epoch [0/5], Step [1940/3236], Loss: 2.2831, Perplexity: 9.8071
# Epoch [0/5], Step [1950/3236], Loss: 2.3456, Perplexity: 10.4396
# Epoch [0/5], Step [1960/3236], Loss: 2.2074, Perplexity: 9.0922
# Epoch [0/5], Step [1970/3236], Loss: 2.3441, Perplexity: 10.4244
# Epoch [0/5], Step [1980/3236], Loss: 2.1557, Perplexity: 8.6336
# Epoch [0/5], Step [1990/3236], Loss: 2.5071, Perplexity: 12.2692
# Epoch [0/5], Step [2000/3236], Loss: 2.4639, Perplexity: 11.7505
# Epoch [0/5], Step [2010/3236], Loss: 2.3553, Perplexity: 10.5417
# Epoch [0/5], Step [2020/3236], Loss: 2.3269, Perplexity: 10.2457
# Epoch [0/5], Step [2030/3236], Loss: 2.2575, Perplexity: 9.5591
# Epoch [0/5], Step [2040/3236], Loss: 2.4440, Perplexity: 11.5186
# Epoch [0/5], Step [2050/3236], Loss: 2.1526, Perplexity: 8.6068
# Epoch [0/5], Step [2060/3236], Loss: 2.4250, Perplexity: 11.3023
# Epoch [0/5], Step [2070/3236], Loss: 2.3812, Perplexity: 10.8177
# Epoch [0/5], Step [2080/3236], Loss: 2.2926, Perplexity: 9.9006
# Epoch [0/5], Step [2090/3236], Loss: 2.5784, Perplexity: 13.1758
# Epoch [0/5], Step [2100/3236], Loss: 2.4859, Perplexity: 12.0119
# Epoch [0/5], Step [2110/3236], Loss: 2.3760, Perplexity: 10.7619
# Epoch [0/5], Step [2120/3236], Loss: 2.4199, Perplexity: 11.2447
# Epoch [0/5], Step [2130/3236], Loss: 2.2955, Perplexity: 9.9299
# Epoch [0/5], Step [2140/3236], Loss: 2.3395, Perplexity: 10.3764
# Epoch [0/5], Step [2150/3236], Loss: 2.3659, Perplexity: 10.6539
# Epoch [0/5], Step [2160/3236], Loss: 2.3795, Perplexity: 10.7990
# Epoch [0/5], Step [2170/3236], Loss: 2.2748, Perplexity: 9.7262
# Epoch [0/5], Step [2180/3236], Loss: 2.3968, Perplexity: 10.9876
# Epoch [0/5], Step [2190/3236], Loss: 2.3655, Perplexity: 10.6498
# Epoch [0/5], Step [2200/3236], Loss: 2.2156, Perplexity: 9.1671
# Epoch [0/5], Step [2210/3236], Loss: 2.2212, Perplexity: 9.2188
# Epoch [0/5], Step [2220/3236], Loss: 2.3031, Perplexity: 10.0048
# Epoch [0/5], Step [2230/3236], Loss: 2.3667, Perplexity: 10.6622
# Epoch [0/5], Step [2240/3236], Loss: 2.2808, Perplexity: 9.7845
# Epoch [0/5], Step [2250/3236], Loss: 2.2502, Perplexity: 9.4893
# Epoch [0/5], Step [2260/3236], Loss: 2.2499, Perplexity: 9.4867
# Epoch [0/5], Step [2270/3236], Loss: 2.2500, Perplexity: 9.4882
# Epoch [0/5], Step [2280/3236], Loss: 2.3724, Perplexity: 10.7231
# Epoch [0/5], Step [2290/3236], Loss: 2.4226, Perplexity: 11.2748
# Epoch [0/5], Step [2300/3236], Loss: 2.2830, Perplexity: 9.8062
# Epoch [0/5], Step [2310/3236], Loss: 2.3147, Perplexity: 10.1223
# Epoch [0/5], Step [2320/3236], Loss: 2.3277, Perplexity: 10.2539
# Epoch [0/5], Step [2330/3236], Loss: 2.4247, Perplexity: 11.2991
# Epoch [0/5], Step [2340/3236], Loss: 2.2978, Perplexity: 9.9522
# Epoch [0/5], Step [2350/3236], Loss: 2.3383, Perplexity: 10.3632
# Epoch [0/5], Step [2360/3236], Loss: 2.3367, Perplexity: 10.3467
# Epoch [0/5], Step [2370/3236], Loss: 2.2842, Perplexity: 9.8182
# Epoch [0/5], Step [2380/3236], Loss: 2.3421, Perplexity: 10.4028
# Epoch [0/5], Step [2390/3236], Loss: 2.3208, Perplexity: 10.1840
# Epoch [0/5], Step [2400/3236], Loss: 2.3140, Perplexity: 10.1151
# Epoch [0/5], Step [2410/3236], Loss: 2.2651, Perplexity: 9.6321
# Epoch [0/5], Step [2420/3236], Loss: 2.0708, Perplexity: 7.9312
# Epoch [0/5], Step [2430/3236], Loss: 2.3175, Perplexity: 10.1498
# Epoch [0/5], Step [2440/3236], Loss: 2.3507, Perplexity: 10.4934
# Epoch [0/5], Step [2450/3236], Loss: 2.2754, Perplexity: 9.7320
# Epoch [0/5], Step [2460/3236], Loss: 2.3011, Perplexity: 9.9852
# Epoch [0/5], Step [2470/3236], Loss: 2.2988, Perplexity: 9.9627
# Epoch [0/5], Step [2480/3236], Loss: 2.3045, Perplexity: 10.0189
# Epoch [0/5], Step [2490/3236], Loss: 2.4216, Perplexity: 11.2641
# Epoch [0/5], Step [2500/3236], Loss: 2.3887, Perplexity: 10.8991
# Epoch [0/5], Step [2510/3236], Loss: 2.2114, Perplexity: 9.1286
# Epoch [0/5], Step [2520/3236], Loss: 2.2827, Perplexity: 9.8033
# Epoch [0/5], Step [2530/3236], Loss: 2.2212, Perplexity: 9.2182
# Epoch [0/5], Step [2540/3236], Loss: 2.2616, Perplexity: 9.5988
# Epoch [0/5], Step [2550/3236], Loss: 2.3069, Perplexity: 10.0430
# Epoch [0/5], Step [2560/3236], Loss: 2.3837, Perplexity: 10.8450
# Epoch [0/5], Step [2570/3236], Loss: 2.2046, Perplexity: 9.0662
# Epoch [0/5], Step [2580/3236], Loss: 2.2575, Perplexity: 9.5592
# Epoch [0/5], Step [2590/3236], Loss: 2.2046, Perplexity: 9.0663
# Epoch [0/5], Step [2600/3236], Loss: 2.2514, Perplexity: 9.5010
# Epoch [0/5], Step [2610/3236], Loss: 2.2763, Perplexity: 9.7405
# Epoch [0/5], Step [2620/3236], Loss: 2.2283, Perplexity: 9.2839
# Epoch [0/5], Step [2630/3236], Loss: 2.3652, Perplexity: 10.6462
# Epoch [0/5], Step [2640/3236], Loss: 2.4695, Perplexity: 11.8162
# Epoch [0/5], Step [2650/3236], Loss: 2.3943, Perplexity: 10.9608
# Epoch [0/5], Step [2660/3236], Loss: 2.3899, Perplexity: 10.9125
# Epoch [0/5], Step [2670/3236], Loss: 2.2949, Perplexity: 9.9230
# Epoch [0/5], Step [2680/3236], Loss: 2.2104, Perplexity: 9.1192
# Epoch [0/5], Step [2690/3236], Loss: 2.2006, Perplexity: 9.0306
# Epoch [0/5], Step [2700/3236], Loss: 2.2473, Perplexity: 9.4621
# Epoch [0/5], Step [2710/3236], Loss: 2.3711, Perplexity: 10.7087
# Epoch [0/5], Step [2720/3236], Loss: 2.3390, Perplexity: 10.3708
# Epoch [0/5], Step [2730/3236], Loss: 2.2123, Perplexity: 9.1369
# Epoch [0/5], Step [2740/3236], Loss: 2.3688, Perplexity: 10.6846
# Epoch [0/5], Step [2750/3236], Loss: 2.2482, Perplexity: 9.4702
# Epoch [0/5], Step [2760/3236], Loss: 2.2652, Perplexity: 9.6332
# Epoch [0/5], Step [2770/3236], Loss: 2.2709, Perplexity: 9.6882
# Epoch [0/5], Step [2780/3236], Loss: 2.3032, Perplexity: 10.0058
# Epoch [0/5], Step [2790/3236], Loss: 2.3494, Perplexity: 10.4796
# Epoch [0/5], Step [2800/3236], Loss: 2.2642, Perplexity: 9.6234
# Epoch [0/5], Step [2810/3236], Loss: 2.4532, Perplexity: 11.6258
# Epoch [0/5], Step [2820/3236], Loss: 2.3052, Perplexity: 10.0258
# Epoch [0/5], Step [2830/3236], Loss: 2.1433, Perplexity: 8.5274
# Epoch [0/5], Step [2840/3236], Loss: 2.3304, Perplexity: 10.2820
# Epoch [0/5], Step [2850/3236], Loss: 2.3249, Perplexity: 10.2253
# Epoch [0/5], Step [2860/3236], Loss: 2.2991, Perplexity: 9.9651
# Epoch [0/5], Step [2870/3236], Loss: 2.2269, Perplexity: 9.2709
# Epoch [0/5], Step [2880/3236], Loss: 2.2713, Perplexity: 9.6924
# Epoch [0/5], Step [2890/3236], Loss: 2.2113, Perplexity: 9.1273
# Epoch [0/5], Step [2900/3236], Loss: 2.3897, Perplexity: 10.9099
# Epoch [0/5], Step [2910/3236], Loss: 2.2701, Perplexity: 9.6808
# Epoch [0/5], Step [2920/3236], Loss: 2.3118, Perplexity: 10.0921
# Epoch [0/5], Step [2930/3236], Loss: 2.2942, Perplexity: 9.9163
# Epoch [0/5], Step [2940/3236], Loss: 2.2664, Perplexity: 9.6449
# Epoch [0/5], Step [2950/3236], Loss: 2.2655, Perplexity: 9.6361
# Epoch [0/5], Step [2960/3236], Loss: 2.1738, Perplexity: 8.7920
# Epoch [0/5], Step [2970/3236], Loss: 2.2657, Perplexity: 9.6375
# Epoch [0/5], Step [2980/3236], Loss: 2.3005, Perplexity: 9.9796
# Epoch [0/5], Step [2990/3236], Loss: 2.2107, Perplexity: 9.1222
# Epoch [0/5], Step [3000/3236], Loss: 2.2814, Perplexity: 9.7906
# Epoch [0/5], Step [3010/3236], Loss: 2.1559, Perplexity: 8.6360
# Epoch [0/5], Step [3020/3236], Loss: 2.2299, Perplexity: 9.2993
# Epoch [0/5], Step [3030/3236], Loss: 2.1094, Perplexity: 8.2437
# Epoch [0/5], Step [3040/3236], Loss: 2.2519, Perplexity: 9.5055
# Epoch [0/5], Step [3050/3236], Loss: 2.4307, Perplexity: 11.3670
# Epoch [0/5], Step [3060/3236], Loss: 2.2488, Perplexity: 9.4762
# Epoch [0/5], Step [3070/3236], Loss: 2.3269, Perplexity: 10.2459
# Epoch [0/5], Step [3080/3236], Loss: 2.1276, Perplexity: 8.3950
# Epoch [0/5], Step [3090/3236], Loss: 2.3802, Perplexity: 10.8075
# Epoch [0/5], Step [3100/3236], Loss: 2.3188, Perplexity: 10.1636
# Epoch [0/5], Step [3110/3236], Loss: 2.2477, Perplexity: 9.4664
# Epoch [0/5], Step [3120/3236], Loss: 2.3165, Perplexity: 10.1400
# Epoch [0/5], Step [3130/3236], Loss: 2.2731, Perplexity: 9.7091
# Epoch [0/5], Step [3140/3236], Loss: 2.3410, Perplexity: 10.3919
# Epoch [0/5], Step [3150/3236], Loss: 2.2146, Perplexity: 9.1578
# Epoch [0/5], Step [3160/3236], Loss: 2.2954, Perplexity: 9.9280
# Epoch [0/5], Step [3170/3236], Loss: 2.1476, Perplexity: 8.5644
# Epoch [0/5], Step [3180/3236], Loss: 2.1348, Perplexity: 8.4556
# Epoch [0/5], Step [3190/3236], Loss: 2.1765, Perplexity: 8.8158
# Epoch [0/5], Step [3200/3236], Loss: 2.3365, Perplexity: 10.3452
# Epoch [0/5], Step [3210/3236], Loss: 2.1139, Perplexity: 8.2806
# Epoch [0/5], Step [3220/3236], Loss: 2.3421, Perplexity: 10.4028
# Epoch [0/5], Step [3230/3236], Loss: 2.2997, Perplexity: 9.9710
# Epoch [1/5], Step [0/3236], Loss: 2.1230, Perplexity: 8.3565
# Epoch [1/5], Step [10/3236], Loss: 2.0831, Perplexity: 8.0297
# Epoch [1/5], Step [20/3236], Loss: 2.2619, Perplexity: 9.6009
# Epoch [1/5], Step [30/3236], Loss: 2.3592, Perplexity: 10.5822
# Epoch [1/5], Step [40/3236], Loss: 2.2151, Perplexity: 9.1624
# Epoch [1/5], Step [50/3236], Loss: 2.3088, Perplexity: 10.0626
# Epoch [1/5], Step [60/3236], Loss: 2.0626, Perplexity: 7.8660
# Epoch [1/5], Step [70/3236], Loss: 2.1478, Perplexity: 8.5658
# Epoch [1/5], Step [80/3236], Loss: 2.2683, Perplexity: 9.6627
# Epoch [1/5], Step [90/3236], Loss: 2.1978, Perplexity: 9.0055
# Epoch [1/5], Step [100/3236], Loss: 2.1670, Perplexity: 8.7318
# Epoch [1/5], Step [110/3236], Loss: 2.1797, Perplexity: 8.8438
# Epoch [1/5], Step [120/3236], Loss: 2.2343, Perplexity: 9.3395
# Epoch [1/5], Step [130/3236], Loss: 2.2473, Perplexity: 9.4623
# Epoch [1/5], Step [140/3236], Loss: 2.2861, Perplexity: 9.8365
# Epoch [1/5], Step [150/3236], Loss: 2.1914, Perplexity: 8.9477
# Epoch [1/5], Step [160/3236], Loss: 2.2415, Perplexity: 9.4079
# Epoch [1/5], Step [170/3236], Loss: 2.2717, Perplexity: 9.6955
# Epoch [1/5], Step [180/3236], Loss: 2.1269, Perplexity: 8.3891
# Epoch [1/5], Step [190/3236], Loss: 2.1655, Perplexity: 8.7187
# Epoch [1/5], Step [200/3236], Loss: 2.1794, Perplexity: 8.8411
# Epoch [1/5], Step [210/3236], Loss: 2.1817, Perplexity: 8.8616
# Epoch [1/5], Step [220/3236], Loss: 2.2053, Perplexity: 9.0730
# Epoch [1/5], Step [230/3236], Loss: 2.1452, Perplexity: 8.5440
# Epoch [1/5], Step [240/3236], Loss: 2.1805, Perplexity: 8.8505
# Epoch [1/5], Step [250/3236], Loss: 2.2574, Perplexity: 9.5580
# Epoch [1/5], Step [260/3236], Loss: 2.1469, Perplexity: 8.5581
# Epoch [1/5], Step [270/3236], Loss: 2.1604, Perplexity: 8.6746
# Epoch [1/5], Step [280/3236], Loss: 2.1198, Perplexity: 8.3297
# Epoch [1/5], Step [290/3236], Loss: 2.1674, Perplexity: 8.7352
# Epoch [1/5], Step [300/3236], Loss: 2.1156, Perplexity: 8.2945
# Epoch [1/5], Step [310/3236], Loss: 2.1349, Perplexity: 8.4560
# Epoch [1/5], Step [320/3236], Loss: 2.1549, Perplexity: 8.6271
# Epoch [1/5], Step [330/3236], Loss: 2.2237, Perplexity: 9.2418
# Epoch [1/5], Step [340/3236], Loss: 2.2864, Perplexity: 9.8397
# Epoch [1/5], Step [350/3236], Loss: 2.0140, Perplexity: 7.4930
# Epoch [1/5], Step [360/3236], Loss: 2.2709, Perplexity: 9.6881
# Epoch [1/5], Step [370/3236], Loss: 2.0247, Perplexity: 7.5736
# Epoch [1/5], Step [380/3236], Loss: 2.1040, Perplexity: 8.1990
# Epoch [1/5], Step [390/3236], Loss: 2.1728, Perplexity: 8.7824
# Epoch [1/5], Step [400/3236], Loss: 2.2054, Perplexity: 9.0743
# Epoch [1/5], Step [410/3236], Loss: 2.1807, Perplexity: 8.8527
# Epoch [1/5], Step [420/3236], Loss: 2.0569, Perplexity: 7.8220
# Epoch [1/5], Step [430/3236], Loss: 2.2409, Perplexity: 9.4014
# Epoch [1/5], Step [440/3236], Loss: 2.2312, Perplexity: 9.3109
# Epoch [1/5], Step [450/3236], Loss: 2.1374, Perplexity: 8.4773
# Epoch [1/5], Step [460/3236], Loss: 2.2082, Perplexity: 9.0995
# Epoch [1/5], Step [470/3236], Loss: 2.1345, Perplexity: 8.4531
# Epoch [1/5], Step [480/3236], Loss: 2.0869, Perplexity: 8.0598
# Epoch [1/5], Step [490/3236], Loss: 2.0640, Perplexity: 7.8777
# Epoch [1/5], Step [500/3236], Loss: 2.0836, Perplexity: 8.0334
# Epoch [1/5], Step [510/3236], Loss: 2.0379, Perplexity: 7.6746
# Epoch [1/5], Step [520/3236], Loss: 2.1355, Perplexity: 8.4609
# Epoch [1/5], Step [530/3236], Loss: 2.2356, Perplexity: 9.3524
# Epoch [1/5], Step [540/3236], Loss: 2.1448, Perplexity: 8.5404
# Epoch [1/5], Step [550/3236], Loss: 2.2352, Perplexity: 9.3481
# Epoch [1/5], Step [560/3236], Loss: 2.1564, Perplexity: 8.6403
# Epoch [1/5], Step [570/3236], Loss: 2.1833, Perplexity: 8.8757
# Epoch [1/5], Step [580/3236], Loss: 2.1543, Perplexity: 8.6221
# Epoch [1/5], Step [590/3236], Loss: 2.0231, Perplexity: 7.5619
# Epoch [1/5], Step [600/3236], Loss: 2.0857, Perplexity: 8.0501
# Epoch [1/5], Step [610/3236], Loss: 2.1116, Perplexity: 8.2612
# Epoch [1/5], Step [620/3236], Loss: 2.1373, Perplexity: 8.4764
# Epoch [1/5], Step [630/3236], Loss: 2.2277, Perplexity: 9.2786
# Epoch [1/5], Step [640/3236], Loss: 2.0023, Perplexity: 7.4062
# Epoch [1/5], Step [650/3236], Loss: 2.2972, Perplexity: 9.9467
# Epoch [1/5], Step [660/3236], Loss: 2.1640, Perplexity: 8.7058
# Epoch [1/5], Step [670/3236], Loss: 2.1640, Perplexity: 8.7062
# Epoch [1/5], Step [680/3236], Loss: 2.1865, Perplexity: 8.9042
# Epoch [1/5], Step [690/3236], Loss: 2.1347, Perplexity: 8.4548
# Epoch [1/5], Step [700/3236], Loss: 2.1757, Perplexity: 8.8086
# Epoch [1/5], Step [710/3236], Loss: 2.0969, Perplexity: 8.1407
# Epoch [1/5], Step [720/3236], Loss: 2.1692, Perplexity: 8.7515
# Epoch [1/5], Step [730/3236], Loss: 2.0795, Perplexity: 8.0008
# Epoch [1/5], Step [740/3236], Loss: 2.1968, Perplexity: 8.9961
# Epoch [1/5], Step [750/3236], Loss: 2.3458, Perplexity: 10.4414
# Epoch [1/5], Step [760/3236], Loss: 2.1630, Perplexity: 8.6968
# Epoch [1/5], Step [770/3236], Loss: 2.1172, Perplexity: 8.3076
# Epoch [1/5], Step [780/3236], Loss: 2.1453, Perplexity: 8.5448
# Epoch [1/5], Step [790/3236], Loss: 2.1622, Perplexity: 8.6902
# Epoch [1/5], Step [800/3236], Loss: 2.0709, Perplexity: 7.9321
# Epoch [1/5], Step [810/3236], Loss: 2.1510, Perplexity: 8.5931
# Epoch [1/5], Step [820/3236], Loss: 2.2619, Perplexity: 9.6011
# Epoch [1/5], Step [830/3236], Loss: 2.2015, Perplexity: 9.0387
# Epoch [1/5], Step [840/3236], Loss: 2.1401, Perplexity: 8.5000
# Epoch [1/5], Step [850/3236], Loss: 2.1500, Perplexity: 8.5852
# Epoch [1/5], Step [860/3236], Loss: 2.1757, Perplexity: 8.8080
# Epoch [1/5], Step [870/3236], Loss: 2.1789, Perplexity: 8.8364
# Epoch [1/5], Step [880/3236], Loss: 2.1352, Perplexity: 8.4587
# Epoch [1/5], Step [890/3236], Loss: 2.1451, Perplexity: 8.5431
# Epoch [1/5], Step [900/3236], Loss: 2.1342, Perplexity: 8.4500
# Epoch [1/5], Step [910/3236], Loss: 2.1882, Perplexity: 8.9193
# Epoch [1/5], Step [920/3236], Loss: 2.3508, Perplexity: 10.4942
# Epoch [1/5], Step [930/3236], Loss: 2.1294, Perplexity: 8.4097
# Epoch [1/5], Step [940/3236], Loss: 2.0817, Perplexity: 8.0183
# Epoch [1/5], Step [950/3236], Loss: 2.0403, Perplexity: 7.6928
# Epoch [1/5], Step [960/3236], Loss: 2.2309, Perplexity: 9.3085
# Epoch [1/5], Step [970/3236], Loss: 2.1897, Perplexity: 8.9329
# Epoch [1/5], Step [980/3236], Loss: 2.1542, Perplexity: 8.6207
# Epoch [1/5], Step [990/3236], Loss: 2.1891, Perplexity: 8.9271
# Epoch [1/5], Step [1000/3236], Loss: 2.0349, Perplexity: 7.6514
# Epoch [1/5], Step [1010/3236], Loss: 2.1855, Perplexity: 8.8949
# Epoch [1/5], Step [1020/3236], Loss: 2.0335, Perplexity: 7.6410
# Epoch [1/5], Step [1030/3236], Loss: 2.0896, Perplexity: 8.0815
# Epoch [1/5], Step [1040/3236], Loss: 2.0086, Perplexity: 7.4532
# Epoch [1/5], Step [1050/3236], Loss: 2.0774, Perplexity: 7.9836
# Epoch [1/5], Step [1060/3236], Loss: 2.0725, Perplexity: 7.9446
# Epoch [1/5], Step [1070/3236], Loss: 2.0843, Perplexity: 8.0392
# Epoch [1/5], Step [1080/3236], Loss: 2.0778, Perplexity: 7.9865
# Epoch [1/5], Step [1090/3236], Loss: 2.2302, Perplexity: 9.3021
# Epoch [1/5], Step [1100/3236], Loss: 2.1771, Perplexity: 8.8210
# Epoch [1/5], Step [1110/3236], Loss: 2.1786, Perplexity: 8.8337
# Epoch [1/5], Step [1120/3236], Loss: 2.2069, Perplexity: 9.0874
# Epoch [1/5], Step [1130/3236], Loss: 2.2419, Perplexity: 9.4109
# Epoch [1/5], Step [1140/3236], Loss: 2.1519, Perplexity: 8.6013
# Epoch [1/5], Step [1150/3236], Loss: 2.3012, Perplexity: 9.9858
# Epoch [1/5], Step [1160/3236], Loss: 2.1331, Perplexity: 8.4409
# Epoch [1/5], Step [1170/3236], Loss: 2.2092, Perplexity: 9.1081
# Epoch [1/5], Step [1180/3236], Loss: 2.1095, Perplexity: 8.2441
# Epoch [1/5], Step [1190/3236], Loss: 2.1012, Perplexity: 8.1761
# Epoch [1/5], Step [1200/3236], Loss: 2.0393, Perplexity: 7.6849
# Epoch [1/5], Step [1210/3236], Loss: 2.1261, Perplexity: 8.3825
# Epoch [1/5], Step [1220/3236], Loss: 2.2019, Perplexity: 9.0420
# Epoch [1/5], Step [1230/3236], Loss: 2.1207, Perplexity: 8.3369
# Epoch [1/5], Step [1240/3236], Loss: 2.1640, Perplexity: 8.7063
# Epoch [1/5], Step [1250/3236], Loss: 2.1605, Perplexity: 8.6757
# Epoch [1/5], Step [1260/3236], Loss: 2.0810, Perplexity: 8.0123
# Epoch [1/5], Step [1270/3236], Loss: 1.9935, Perplexity: 7.3413
# Epoch [1/5], Step [1280/3236], Loss: 2.1085, Perplexity: 8.2359
# Epoch [1/5], Step [1290/3236], Loss: 2.1730, Perplexity: 8.7847
# Epoch [1/5], Step [1300/3236], Loss: 2.1167, Perplexity: 8.3033
# Epoch [1/5], Step [1310/3236], Loss: 2.1654, Perplexity: 8.7183
# Epoch [1/5], Step [1320/3236], Loss: 2.1179, Perplexity: 8.3133
# Epoch [1/5], Step [1330/3236], Loss: 2.0828, Perplexity: 8.0266
# Epoch [1/5], Step [1340/3236], Loss: 2.2256, Perplexity: 9.2590
# Epoch [1/5], Step [1350/3236], Loss: 2.1934, Perplexity: 8.9656
# Epoch [1/5], Step [1360/3236], Loss: 2.1841, Perplexity: 8.8827
# Epoch [1/5], Step [1370/3236], Loss: 2.0064, Perplexity: 7.4362
# Epoch [1/5], Step [1380/3236], Loss: 2.2380, Perplexity: 9.3741
# Epoch [1/5], Step [1390/3236], Loss: 1.9561, Perplexity: 7.0717
# Epoch [1/5], Step [1400/3236], Loss: 2.1533, Perplexity: 8.6131
# Epoch [1/5], Step [1410/3236], Loss: 2.2193, Perplexity: 9.2011
# Epoch [1/5], Step [1420/3236], Loss: 2.1063, Perplexity: 8.2179
# Epoch [1/5], Step [1430/3236], Loss: 2.0826, Perplexity: 8.0256
# Epoch [1/5], Step [1440/3236], Loss: 2.1554, Perplexity: 8.6316
# Epoch [1/5], Step [1450/3236], Loss: 2.1354, Perplexity: 8.4606
# Epoch [1/5], Step [1460/3236], Loss: 2.0281, Perplexity: 7.5998
# Epoch [1/5], Step [1470/3236], Loss: 1.9925, Perplexity: 7.3340
# Epoch [1/5], Step [1480/3236], Loss: 2.0219, Perplexity: 7.5527
# Epoch [1/5], Step [1490/3236], Loss: 2.1932, Perplexity: 8.9637
# Epoch [1/5], Step [1500/3236], Loss: 2.1228, Perplexity: 8.3545
# Epoch [1/5], Step [1510/3236], Loss: 2.1403, Perplexity: 8.5016
# Epoch [1/5], Step [1520/3236], Loss: 2.1967, Perplexity: 8.9950
# Epoch [1/5], Step [1530/3236], Loss: 2.2007, Perplexity: 9.0311
# Epoch [1/5], Step [1540/3236], Loss: 2.1961, Perplexity: 8.9896
# Epoch [1/5], Step [1550/3236], Loss: 2.0788, Perplexity: 7.9952
# Epoch [1/5], Step [1560/3236], Loss: 2.1319, Perplexity: 8.4308
# Epoch [1/5], Step [1570/3236], Loss: 2.1734, Perplexity: 8.7880
# Epoch [1/5], Step [1580/3236], Loss: 2.2421, Perplexity: 9.4127
# Epoch [1/5], Step [1590/3236], Loss: 2.2066, Perplexity: 9.0845
# Epoch [1/5], Step [1600/3236], Loss: 2.0698, Perplexity: 7.9230
# Epoch [1/5], Step [1610/3236], Loss: 2.0621, Perplexity: 7.8627
# Epoch [1/5], Step [1620/3236], Loss: 2.0903, Perplexity: 8.0872
# Epoch [1/5], Step [1630/3236], Loss: 2.1377, Perplexity: 8.4800
# Epoch [1/5], Step [1640/3236], Loss: 2.0667, Perplexity: 7.8987
# Epoch [1/5], Step [1650/3236], Loss: 2.1275, Perplexity: 8.3936
# Epoch [1/5], Step [1660/3236], Loss: 2.1596, Perplexity: 8.6676
# Epoch [1/5], Step [1670/3236], Loss: 2.0358, Perplexity: 7.6586
# Epoch [1/5], Step [1680/3236], Loss: 2.0435, Perplexity: 7.7176
# Epoch [1/5], Step [1690/3236], Loss: 2.1178, Perplexity: 8.3127
# Epoch [1/5], Step [1700/3236], Loss: 2.1252, Perplexity: 8.3749
# Epoch [1/5], Step [1710/3236], Loss: 2.1019, Perplexity: 8.1820
# Epoch [1/5], Step [1720/3236], Loss: 2.0390, Perplexity: 7.6827
# Epoch [1/5], Step [1730/3236], Loss: 2.0934, Perplexity: 8.1128
# Epoch [1/5], Step [1740/3236], Loss: 2.1127, Perplexity: 8.2703
# Epoch [1/5], Step [1750/3236], Loss: 2.2370, Perplexity: 9.3655
# Epoch [1/5], Step [1760/3236], Loss: 2.1733, Perplexity: 8.7875
# Epoch [1/5], Step [1770/3236], Loss: 2.2442, Perplexity: 9.4328
# Epoch [1/5], Step [1780/3236], Loss: 2.0878, Perplexity: 8.0673
# Epoch [1/5], Step [1790/3236], Loss: 2.1110, Perplexity: 8.2567
# Epoch [1/5], Step [1800/3236], Loss: 2.1474, Perplexity: 8.5629
# Epoch [1/5], Step [1810/3236], Loss: 2.1177, Perplexity: 8.3121
# Epoch [1/5], Step [1820/3236], Loss: 2.1416, Perplexity: 8.5132
# Epoch [1/5], Step [1830/3236], Loss: 1.9662, Perplexity: 7.1436
# Epoch [1/5], Step [1840/3236], Loss: 2.0871, Perplexity: 8.0617
# Epoch [1/5], Step [1850/3236], Loss: 2.1206, Perplexity: 8.3362
# Epoch [1/5], Step [1860/3236], Loss: 2.1469, Perplexity: 8.5585
# Epoch [1/5], Step [1870/3236], Loss: 2.1357, Perplexity: 8.4630
# Epoch [1/5], Step [1880/3236], Loss: 2.1623, Perplexity: 8.6913
# Epoch [1/5], Step [1890/3236], Loss: 2.1179, Perplexity: 8.3141
# Epoch [1/5], Step [1900/3236], Loss: 2.1441, Perplexity: 8.5345
# Epoch [1/5], Step [1910/3236], Loss: 2.2517, Perplexity: 9.5043
# Epoch [1/5], Step [1920/3236], Loss: 2.0801, Perplexity: 8.0051
# Epoch [1/5], Step [1930/3236], Loss: 2.1508, Perplexity: 8.5916
# Epoch [1/5], Step [1940/3236], Loss: 2.1123, Perplexity: 8.2671
# Epoch [1/5], Step [1950/3236], Loss: 2.1238, Perplexity: 8.3629
# Epoch [1/5], Step [1960/3236], Loss: 2.1413, Perplexity: 8.5103
# Epoch [1/5], Step [1970/3236], Loss: 2.2848, Perplexity: 9.8234
# Epoch [1/5], Step [1980/3236], Loss: 2.1405, Perplexity: 8.5034
# Epoch [1/5], Step [1990/3236], Loss: 2.0437, Perplexity: 7.7188
# Epoch [1/5], Step [2000/3236], Loss: 2.1394, Perplexity: 8.4942
# Epoch [1/5], Step [2010/3236], Loss: 2.1402, Perplexity: 8.5012
# Epoch [1/5], Step [2020/3236], Loss: 2.1950, Perplexity: 8.9802
# Epoch [1/5], Step [2030/3236], Loss: 2.0904, Perplexity: 8.0884
# Epoch [1/5], Step [2040/3236], Loss: 2.3394, Perplexity: 10.3749
# Epoch [1/5], Step [2050/3236], Loss: 2.1263, Perplexity: 8.3840
# Epoch [1/5], Step [2060/3236], Loss: 2.1652, Perplexity: 8.7167
# Epoch [1/5], Step [2070/3236], Loss: 2.1548, Perplexity: 8.6260
# Epoch [1/5], Step [2080/3236], Loss: 2.0698, Perplexity: 7.9230
# Epoch [1/5], Step [2090/3236], Loss: 2.0583, Perplexity: 7.8325
# Epoch [1/5], Step [2100/3236], Loss: 2.1663, Perplexity: 8.7263
# Epoch [1/5], Step [2110/3236], Loss: 2.0809, Perplexity: 8.0120
# Epoch [1/5], Step [2120/3236], Loss: 2.0834, Perplexity: 8.0316
# Epoch [1/5], Step [2130/3236], Loss: 2.1498, Perplexity: 8.5834
# Epoch [1/5], Step [2140/3236], Loss: 2.1828, Perplexity: 8.8710
# Epoch [1/5], Step [2150/3236], Loss: 2.0186, Perplexity: 7.5279
# Epoch [1/5], Step [2160/3236], Loss: 2.1870, Perplexity: 8.9084
# Epoch [1/5], Step [2170/3236], Loss: 2.0456, Perplexity: 7.7334
# Epoch [1/5], Step [2180/3236], Loss: 2.1511, Perplexity: 8.5941
# Epoch [1/5], Step [2190/3236], Loss: 2.0848, Perplexity: 8.0432
# Epoch [1/5], Step [2200/3236], Loss: 2.1106, Perplexity: 8.2533
# Epoch [1/5], Step [2210/3236], Loss: 2.2004, Perplexity: 9.0287
# Epoch [1/5], Step [2220/3236], Loss: 2.0791, Perplexity: 7.9974
# Epoch [1/5], Step [2230/3236], Loss: 2.0710, Perplexity: 7.9328
# Epoch [1/5], Step [2240/3236], Loss: 2.0002, Perplexity: 7.3906
# Epoch [1/5], Step [2250/3236], Loss: 2.1051, Perplexity: 8.2075
# Epoch [1/5], Step [2260/3236], Loss: 2.1901, Perplexity: 8.9363
# Epoch [1/5], Step [2270/3236], Loss: 2.1149, Perplexity: 8.2889
# Epoch [1/5], Step [2280/3236], Loss: 2.1185, Perplexity: 8.3190
# Epoch [1/5], Step [2290/3236], Loss: 2.0540, Perplexity: 7.7991
# Epoch [1/5], Step [2300/3236], Loss: 2.1490, Perplexity: 8.5765
# Epoch [1/5], Step [2310/3236], Loss: 2.2195, Perplexity: 9.2026
# Epoch [1/5], Step [2320/3236], Loss: 2.0727, Perplexity: 7.9466
# Epoch [1/5], Step [2330/3236], Loss: 2.0893, Perplexity: 8.0789
# Epoch [1/5], Step [2340/3236], Loss: 2.0995, Perplexity: 8.1622
# Epoch [1/5], Step [2350/3236], Loss: 2.0700, Perplexity: 7.9248
# Epoch [1/5], Step [2360/3236], Loss: 2.1315, Perplexity: 8.4274
# Epoch [1/5], Step [2370/3236], Loss: 2.0822, Perplexity: 8.0222
# Epoch [1/5], Step [2380/3236], Loss: 1.9353, Perplexity: 6.9263
# Epoch [1/5], Step [2390/3236], Loss: 2.1593, Perplexity: 8.6650
# Epoch [1/5], Step [2400/3236], Loss: 2.0967, Perplexity: 8.1389
# Epoch [1/5], Step [2410/3236], Loss: 2.2104, Perplexity: 9.1191
# Epoch [1/5], Step [2420/3236], Loss: 2.0794, Perplexity: 7.9998
# Epoch [1/5], Step [2430/3236], Loss: 2.0527, Perplexity: 7.7891
# Epoch [1/5], Step [2440/3236], Loss: 2.0768, Perplexity: 7.9790
# Epoch [1/5], Step [2450/3236], Loss: 1.9604, Perplexity: 7.1022
# Epoch [1/5], Step [2460/3236], Loss: 2.0441, Perplexity: 7.7219
# Epoch [1/5], Step [2470/3236], Loss: 1.9687, Perplexity: 7.1616
# Epoch [1/5], Step [2480/3236], Loss: 2.0753, Perplexity: 7.9671
# Epoch [1/5], Step [2490/3236], Loss: 2.3117, Perplexity: 10.0915
# Epoch [1/5], Step [2500/3236], Loss: 2.1258, Perplexity: 8.3799
# Epoch [1/5], Step [2510/3236], Loss: 2.0031, Perplexity: 7.4122
# Epoch [1/5], Step [2520/3236], Loss: 2.0033, Perplexity: 7.4137
# Epoch [1/5], Step [2530/3236], Loss: 2.1215, Perplexity: 8.3440
# Epoch [1/5], Step [2540/3236], Loss: 2.1538, Perplexity: 8.6179
# Epoch [1/5], Step [2550/3236], Loss: 2.1854, Perplexity: 8.8939
# Epoch [1/5], Step [2560/3236], Loss: 2.1716, Perplexity: 8.7721
# Epoch [1/5], Step [2570/3236], Loss: 2.1700, Perplexity: 8.7581
# Epoch [1/5], Step [2580/3236], Loss: 2.1736, Perplexity: 8.7902
# Epoch [1/5], Step [2590/3236], Loss: 2.1241, Perplexity: 8.3654
# Epoch [1/5], Step [2600/3236], Loss: 2.1559, Perplexity: 8.6360
# Epoch [1/5], Step [2610/3236], Loss: 2.0737, Perplexity: 7.9543
# Epoch [1/5], Step [2620/3236], Loss: 2.3104, Perplexity: 10.0781
# Epoch [1/5], Step [2630/3236], Loss: 2.1608, Perplexity: 8.6782
# Epoch [1/5], Step [2640/3236], Loss: 2.1576, Perplexity: 8.6505
# Epoch [1/5], Step [2650/3236], Loss: 2.1651, Perplexity: 8.7154
# Epoch [1/5], Step [2660/3236], Loss: 2.2699, Perplexity: 9.6788
# Epoch [1/5], Step [2670/3236], Loss: 2.2826, Perplexity: 9.8019
# Epoch [1/5], Step [2680/3236], Loss: 2.1625, Perplexity: 8.6926
# Epoch [1/5], Step [2690/3236], Loss: 2.0798, Perplexity: 8.0027
# Epoch [1/5], Step [2700/3236], Loss: 2.1015, Perplexity: 8.1782
# Epoch [1/5], Step [2710/3236], Loss: 2.0487, Perplexity: 7.7577
# Epoch [1/5], Step [2720/3236], Loss: 2.1801, Perplexity: 8.8476
# Epoch [1/5], Step [2730/3236], Loss: 2.1190, Perplexity: 8.3230
# Epoch [1/5], Step [2740/3236], Loss: 2.1211, Perplexity: 8.3403
# Epoch [1/5], Step [2750/3236], Loss: 2.2086, Perplexity: 9.1034
# Epoch [1/5], Step [2760/3236], Loss: 2.0875, Perplexity: 8.0648
# Epoch [1/5], Step [2770/3236], Loss: 2.0151, Perplexity: 7.5015
# Epoch [1/5], Step [2780/3236], Loss: 2.0087, Perplexity: 7.4537
# Epoch [1/5], Step [2790/3236], Loss: 2.1658, Perplexity: 8.7215
# Epoch [1/5], Step [2800/3236], Loss: 2.1981, Perplexity: 9.0076
# Epoch [1/5], Step [2810/3236], Loss: 2.0854, Perplexity: 8.0478
# Epoch [1/5], Step [2820/3236], Loss: 2.0434, Perplexity: 7.7170
# Epoch [1/5], Step [2830/3236], Loss: 1.9956, Perplexity: 7.3566
# Epoch [1/5], Step [2840/3236], Loss: 2.1625, Perplexity: 8.6925
# Epoch [1/5], Step [2850/3236], Loss: 2.0482, Perplexity: 7.7536
# Epoch [1/5], Step [2860/3236], Loss: 2.1514, Perplexity: 8.5965
# Epoch [1/5], Step [2870/3236], Loss: 2.0068, Perplexity: 7.4397
# Epoch [1/5], Step [2880/3236], Loss: 2.0633, Perplexity: 7.8716
# Epoch [1/5], Step [2890/3236], Loss: 2.0505, Perplexity: 7.7720
# Epoch [1/5], Step [2900/3236], Loss: 2.1409, Perplexity: 8.5075
# Epoch [1/5], Step [2910/3236], Loss: 2.1267, Perplexity: 8.3872
# Epoch [1/5], Step [2920/3236], Loss: 1.9807, Perplexity: 7.2476
# Epoch [1/5], Step [2930/3236], Loss: 2.0550, Perplexity: 7.8070
# Epoch [1/5], Step [2940/3236], Loss: 2.1051, Perplexity: 8.2076
# Epoch [1/5], Step [2950/3236], Loss: 2.1464, Perplexity: 8.5537
# Epoch [1/5], Step [2960/3236], Loss: 1.9936, Perplexity: 7.3420
# Epoch [1/5], Step [2970/3236], Loss: 2.0865, Perplexity: 8.0565
# Epoch [1/5], Step [2980/3236], Loss: 2.0093, Perplexity: 7.4584
# Epoch [1/5], Step [2990/3236], Loss: 2.1064, Perplexity: 8.2183
# Epoch [1/5], Step [3000/3236], Loss: 2.0886, Perplexity: 8.0734
# Epoch [1/5], Step [3010/3236], Loss: 1.9485, Perplexity: 7.0182
# Epoch [1/5], Step [3020/3236], Loss: 2.1887, Perplexity: 8.9240
# Epoch [1/5], Step [3030/3236], Loss: 2.0253, Perplexity: 7.5787
# Epoch [1/5], Step [3040/3236], Loss: 2.0761, Perplexity: 7.9730
# Epoch [1/5], Step [3050/3236], Loss: 2.1233, Perplexity: 8.3587
# Epoch [1/5], Step [3060/3236], Loss: 2.0413, Perplexity: 7.7003
# Epoch [1/5], Step [3070/3236], Loss: 2.1010, Perplexity: 8.1740
# Epoch [1/5], Step [3080/3236], Loss: 2.0811, Perplexity: 8.0131
# Epoch [1/5], Step [3090/3236], Loss: 2.1464, Perplexity: 8.5542
# Epoch [1/5], Step [3100/3236], Loss: 2.0140, Perplexity: 7.4932
# Epoch [1/5], Step [3110/3236], Loss: 2.0553, Perplexity: 7.8094
# Epoch [1/5], Step [3120/3236], Loss: 2.1551, Perplexity: 8.6291
# Epoch [1/5], Step [3130/3236], Loss: 2.0159, Perplexity: 7.5079
# Epoch [1/5], Step [3140/3236], Loss: 2.1616, Perplexity: 8.6847
# Epoch [1/5], Step [3150/3236], Loss: 2.1768, Perplexity: 8.8184
# Epoch [1/5], Step [3160/3236], Loss: 2.1242, Perplexity: 8.3666
# Epoch [1/5], Step [3170/3236], Loss: 1.9933, Perplexity: 7.3395
# Epoch [1/5], Step [3180/3236], Loss: 2.0472, Perplexity: 7.7460
# Epoch [1/5], Step [3190/3236], Loss: 2.1534, Perplexity: 8.6139
# Epoch [1/5], Step [3200/3236], Loss: 2.3171, Perplexity: 10.1466
# Epoch [1/5], Step [3210/3236], Loss: 2.0306, Perplexity: 7.6184
# Epoch [1/5], Step [3220/3236], Loss: 2.0667, Perplexity: 7.8989
# Epoch [1/5], Step [3230/3236], Loss: 2.0001, Perplexity: 7.3901
# Epoch [2/5], Step [0/3236], Loss: 1.9653, Perplexity: 7.1374
# Epoch [2/5], Step [10/3236], Loss: 2.0917, Perplexity: 8.0987
# Epoch [2/5], Step [20/3236], Loss: 2.0579, Perplexity: 7.8297
# Epoch [2/5], Step [30/3236], Loss: 2.0462, Perplexity: 7.7381
# Epoch [2/5], Step [40/3236], Loss: 1.9997, Perplexity: 7.3867
# Epoch [2/5], Step [50/3236], Loss: 1.9372, Perplexity: 6.9393
# Epoch [2/5], Step [60/3236], Loss: 2.0101, Perplexity: 7.4638
# Epoch [2/5], Step [70/3236], Loss: 2.0128, Perplexity: 7.4842
# Epoch [2/5], Step [80/3236], Loss: 1.8716, Perplexity: 6.4985
# Epoch [2/5], Step [90/3236], Loss: 2.0264, Perplexity: 7.5865
# Epoch [2/5], Step [100/3236], Loss: 1.9973, Perplexity: 7.3691
# Epoch [2/5], Step [110/3236], Loss: 1.9355, Perplexity: 6.9278
# Epoch [2/5], Step [120/3236], Loss: 2.0623, Perplexity: 7.8639
# Epoch [2/5], Step [130/3236], Loss: 1.9527, Perplexity: 7.0479
# Epoch [2/5], Step [140/3236], Loss: 1.9620, Perplexity: 7.1137
# Epoch [2/5], Step [150/3236], Loss: 2.0002, Perplexity: 7.3904
# Epoch [2/5], Step [160/3236], Loss: 1.9729, Perplexity: 7.1918
# Epoch [2/5], Step [170/3236], Loss: 2.0045, Perplexity: 7.4225
# Epoch [2/5], Step [180/3236], Loss: 1.9372, Perplexity: 6.9395
# Epoch [2/5], Step [190/3236], Loss: 2.0944, Perplexity: 8.1206
# Epoch [2/5], Step [200/3236], Loss: 1.9847, Perplexity: 7.2771
# Epoch [2/5], Step [210/3236], Loss: 2.0289, Perplexity: 7.6054
# Epoch [2/5], Step [220/3236], Loss: 1.9562, Perplexity: 7.0723
# Epoch [2/5], Step [230/3236], Loss: 2.0245, Perplexity: 7.5724
# Epoch [2/5], Step [240/3236], Loss: 2.0525, Perplexity: 7.7877
# Epoch [2/5], Step [250/3236], Loss: 2.0045, Perplexity: 7.4227
# Epoch [2/5], Step [260/3236], Loss: 2.0181, Perplexity: 7.5243
# Epoch [2/5], Step [270/3236], Loss: 1.9965, Perplexity: 7.3635
# Epoch [2/5], Step [280/3236], Loss: 2.0558, Perplexity: 7.8129
# Epoch [2/5], Step [290/3236], Loss: 1.9558, Perplexity: 7.0698
# Epoch [2/5], Step [300/3236], Loss: 1.9374, Perplexity: 6.9404
# Epoch [2/5], Step [310/3236], Loss: 1.9777, Perplexity: 7.2262
# Epoch [2/5], Step [320/3236], Loss: 2.0232, Perplexity: 7.5621
# Epoch [2/5], Step [330/3236], Loss: 1.9721, Perplexity: 7.1861
# Epoch [2/5], Step [340/3236], Loss: 2.0766, Perplexity: 7.9774
# Epoch [2/5], Step [350/3236], Loss: 2.0292, Perplexity: 7.6081
# Epoch [2/5], Step [360/3236], Loss: 1.9662, Perplexity: 7.1431
# Epoch [2/5], Step [370/3236], Loss: 2.0146, Perplexity: 7.4981
# Epoch [2/5], Step [380/3236], Loss: 1.9820, Perplexity: 7.2574
# Epoch [2/5], Step [390/3236], Loss: 2.0427, Perplexity: 7.7112
# Epoch [2/5], Step [400/3236], Loss: 1.9073, Perplexity: 6.7351
# Epoch [2/5], Step [410/3236], Loss: 2.0201, Perplexity: 7.5389
# Epoch [2/5], Step [420/3236], Loss: 1.9722, Perplexity: 7.1865
# Epoch [2/5], Step [430/3236], Loss: 1.9836, Perplexity: 7.2692
# Epoch [2/5], Step [440/3236], Loss: 1.9647, Perplexity: 7.1325
# Epoch [2/5], Step [450/3236], Loss: 2.0197, Perplexity: 7.5363
# Epoch [2/5], Step [460/3236], Loss: 2.0037, Perplexity: 7.4168
# Epoch [2/5], Step [470/3236], Loss: 1.9299, Perplexity: 6.8891
# Epoch [2/5], Step [480/3236], Loss: 1.8592, Perplexity: 6.4189
# Epoch [2/5], Step [490/3236], Loss: 2.1236, Perplexity: 8.3612
# Epoch [2/5], Step [500/3236], Loss: 2.1486, Perplexity: 8.5725
# Epoch [2/5], Step [510/3236], Loss: 2.0096, Perplexity: 7.4606
# Epoch [2/5], Step [520/3236], Loss: 2.0571, Perplexity: 7.8234
# Epoch [2/5], Step [530/3236], Loss: 1.9733, Perplexity: 7.1940
# Epoch [2/5], Step [540/3236], Loss: 1.9463, Perplexity: 7.0026
# Epoch [2/5], Step [550/3236], Loss: 2.0493, Perplexity: 7.7623
# Epoch [2/5], Step [560/3236], Loss: 2.0056, Perplexity: 7.4304
# Epoch [2/5], Step [570/3236], Loss: 2.0746, Perplexity: 7.9617
# Epoch [2/5], Step [580/3236], Loss: 2.0016, Perplexity: 7.4009
# Epoch [2/5], Step [590/3236], Loss: 1.9671, Perplexity: 7.1496
# Epoch [2/5], Step [600/3236], Loss: 2.1880, Perplexity: 8.9171

# %% [markdown]
# ## predict caption

# %%
image_file_path = 'sample.jpg'
 

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
 

def load_image(image_file_path, transform=None):
    img = Image.open(image_file_path).convert('RGB')
    img = img.resize([224, 224], Image.LANCZOS)
    
    if transform is not None:
        img = transform(img).unsqueeze(0)
    
    return img
 

# Image preprocessing
transform = transforms.Compose([
    transforms.ToTensor(), 
    transforms.Normalize((0.485, 0.456, 0.406), 
                         (0.229, 0.224, 0.225))])


# Load vocabulary wrapper
with open('data_dir/vocabulary.pkl', 'rb') as f:
    vocabulary = pickle.load(f)


# Build models
encoder_model = CNNModel(256).eval()  # eval mode (batchnorm uses moving mean/variance)
decoder_model = LSTMModel(256, 512, len(vocabulary), 1)
encoder_model = encoder_model.to(device)
decoder_model = decoder_model.to(device)


# Load the trained model parameters
encoder_model.load_state_dict(torch.load('models_dir/encoder-2-3000.ckpt'))
decoder_model.load_state_dict(torch.load('models_dir/decoder-2-3000.ckpt'))


# Prepare an image
img = load_image(image_file_path, transform)
img_tensor = img.to(device)


# Generate an caption from the image
feat = encoder_model(img_tensor)
sampled_indices = decoder_model.sample(feat)
sampled_indices = sampled_indices[0].cpu().numpy()          # (1, max_seq_length) -> (max_seq_length)


# Convert word_ids to words
predicted_caption = []
for token_index in sampled_indices:
    word = vocabulary.i2w[token_index]
    predicted_caption.append(word)
    if word == '<end>':
        break
predicted_sentence = ' '.join(predicted_caption)


# Print out the image and the generated caption
print (predicted_sentence)
img = Image.open(image_file_path)
plt.imshow(np.asarray(img))
